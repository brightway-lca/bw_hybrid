# %% [markdown]
# ### 0.0 follow setup instructions
#
# ℹ️ use [`pylcaio.yml`](https://github.com/michaelweinold/config_conda/blob/main/pylcaio.yml) to set up working conda environment.
#
# ### 0.1. imports
# #### 0.1.1. regular imports

# %%
# i/o
import sys
import os
from pathlib import Path
import gzip
import pickle
import git
import json
# os specific settings
import platform
# configuration
import yaml
# lca
import ecospold2matrix as e2m
import pymrio
#import brightway2 as bw
# type hints
from ecospold2matrix import ecospold2matrix
from pymrio import IOSystem
# data science
import pandas as pd
import numpy as np
# deep copy
import copy

# %% [markdown]
# #### 0.1.2. load configuration file

# %%
with open('../config.yaml', 'r') as filestream:
    config = yaml.load(filestream, Loader = yaml.FullLoader)

# %% [markdown]
# #### 0.1.3. load `pylcaio`

# %%
sys.path.append(os.path.join(Path.home(), config['pylcaio'])) # required for local import of pylcaio
import pylcaio

# %% [markdown]
# ### 0.2. file paths
# #### 0.2.1. directories

# %%
# %%capture
# home directory
print(path_dir_home := Path.home())
print(path_dir_repo := git.Repo('.', search_parent_directories=True).working_tree_dir)
# input directory
print(path_dir_databases := os.path.join(path_dir_home, config['path_dir_databases']))
# output directories
print(path_dir_data := os.path.join(path_dir_home, config['path_dir_data']))
print(path_dir_pylcaio := os.path.join(path_dir_home, path_dir_data, config['path_dir_pylcaio']))
print(path_dir_pymrio := os.path.join(path_dir_home, path_dir_data, config['path_dir_pymrio']))
print(path_dir_e2m := os.path.join(path_dir_home, path_dir_data, config['path_dir_e2m']))

# %% [markdown]
# #### 0.2.2. files

# %%
# %%capture
# databases
print(path_exiobase := os.path.join(path_dir_home, path_dir_databases, config['exiobase']))
print(path_dir_ecoinvent := os.path.join(path_dir_home, path_dir_databases, config['ecoinvent']))
# pylcaio output
print(path_pylcaio_database_loader_class_instance := os.path.join(path_dir_pylcaio, config['pylcaio_database_loader_class_instance']))
print(path_pylcaio_class_instance_before_hybrid := os.path.join(path_dir_pylcaio, config['pylcaio_class_instance_before_hybrid']))
print(path_pylcaio_class_instance_after_hybrid := os.path.join(path_dir_pylcaio, config['pylcaio_class_instance_after_hybrid']))
# pymrio output
print(path_pymrio_class_instance := os.path.join(path_dir_pymrio, config['pymrio_class_instance']))
# e2m output
print(e2m_project_name := config['e2m_project_name'])
print(path_file_e2m_pickle := os.path.join(path_dir_e2m, e2m_project_name + config['e2m_pickle_filename']))

# %%
# %%capture
print(path_dict_io_countries_per_lca_region := os.path.join(path_dir_repo, config['path_dict_io_countries_per_lca_region']))
print(path_list_io_countries_and_regions := os.path.join(path_dir_repo, config['path_list_io_countries_and_regions']))

# %%
with open(file = path_dict_io_countries_per_lca_region, mode = 'r', encoding = 'utf-8') as filestream:
    dict_io_countries_per_lca_region: dict = json.load(fp = filestream)
with open(file = path_list_io_countries_and_regions, mode = 'r', encoding = 'utf-8') as filestream:
    list_io_countries_and_regions: list = json.load(fp = filestream)

# %%
with open(path_pylcaio_class_instance_before_hybrid, 'rb') as file_in:
    pylcaio_object_before_hybrid: pylcaio.LCAIO = pd.read_pickle(file_in)

# %% [markdown]
# #### 1.1. function implementation

# %% [markdown]
# PRO_f dataframe:
#
# | index | activityNameId | io_geography |
# | ----- | -------------- | ------------ |
# | 10 | 1 | RoW |
# | 11 | 1 | CH |
# | 12 | 1 | AT |
# | 13 | 2 | RoW |
# | 14 | 2 | DE |
# | 15 | 2 | CH |
# | 16 | 3 | FR |
# | 17 | 3 | BE |
# | 18 | 4 | RoW |
# | 19 | 4 | CH |
# | 20 | 4 | AT |
#
# should look like:
#
# | activityNameId | io_geography_list | RoW_region |
# | -------------- | ----------------- | ---------- |
# | 1 | RoW, CH, AT | RoW(1) |
# | 2 | RoW, DE, CH | RoW(2) |
# | 4 | RoW, CH, AT | RoW(1) |
#
# where for activityNameId == 1, RoW region is list_io_countries - [CH, AT]

# %% [markdown]
# check: https://stackoverflow.com/a/53343046

# %%
# smart implementation

def identify_rest_of_world_regions(
    df: pd.DataFrame,
    list_io_countries_and_regions: list,
    dict_io_countries_per_lca_region: dict
) -> pd.DataFrame:
    """
    bananas!

    Args:
        df (pd.DataFrame): _description_
        list_io_countries_and_regions (list): _description_
        dict_io_countries_per_lca_region (dict): _description_

    Returns:
        pd.DataFrame: _description_
    """

    df_aggregated = pd.DataFrame(
        data = df.groupby('activityNameId')['io_geography'].apply(tuple)
    )
    
    df_aggregated: pd.DataFrame(
        data =  df_aggregated['io_geography'].apply(
            lambda x: bool(set(x) & set(['RoW']))
        )
    )

    unique_rest_of_world_regions = pd.DataFrame(df['io_geography'].unique())
    unique_rest_of_world_regions['rest_of_world_index'] = ['RoW({})'.format(i) for i in unique_rest_of_world_regions.index]

    df_aggregated.merge(
        right = unique_rest_of_world_regions,
        how = 'left',
        on = 'io_geography'
    )

    # remove 'RoW'

    df[df['list_io_geography'].isin['RoW']]

    return df

# %%
df = pd.DataFrame(
        data = PRO_f.groupby('activityNameId')['io_geography'].apply(tuple)
    )

# %%
testdf = pd.DataFrame(df['io_geography'].unique())

# %%
testdf.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [75], line 1
# ----> 1 testdf.index()
#
# TypeError: 'RangeIndex' object is not callable

# %%
testdf['ind'] = ['RoW({})'.format(i) for i in testdf.index]

# %%
testdf
# Out:
#                                                      0       ind
# 0                                               (GLO,)    RoW(0)
# 1    (HR, MX, WA, LT, HR, LT, WA, RU, ID, WL, LV, W...    RoW(1)
# 2                (CH, RoW, Europe without Switzerland)    RoW(2)
# 3                                           (RER, RoW)    RoW(3)
# 4                 (BR, BR, US, US, RER, RoW, RoW, RER)    RoW(4)
# ..                                                 ...       ...
# 539                                       (WE, WE, WE)  RoW(539)
# 540                    (UCTE without Germany, RoW, DE)  RoW(540)
# 541  (WE, ES, RO, SI, SE, GB, FI, GR, AT, PL, CY, B...  RoW(541)
# 542  (NO, WM, CN, FI, GB, IT, EE, CN, KR, JP, WE, B...  RoW(542)
# 543                          (RoW, CH, RU, DE, FR, US)  RoW(543)
#
# [544 rows x 2 columns]

# %%
test: np.ndarray[list] = df['io_geography'].unique()

# %%
test
# Out:
# array([('GLO',),
#        ('HR', 'MX', 'WA', 'LT', 'HR', 'LT', 'WA', 'RU', 'ID', 'WL', 'LV', 'WL', 'TW', 'ZA', 'BG', 'MX', 'BG', 'RoW', 'WE', 'RU', 'WA', 'EE', 'WL', 'ID', 'LV', 'TR', 'ZA', 'TR', 'CH', 'WF', 'CH', 'EE', 'WA', 'TW', 'WF', 'RoW', 'WE', 'WL'),
#        ('CH', 'RoW', 'Europe without Switzerland'), ('RER', 'RoW'),
#        ('BR', 'BR', 'US', 'US', 'RER', 'RoW', 'RoW', 'RER'),
#        ('RoW', 'WF', 'RU', 'NO', 'NL', 'DE'), ('CH', 'RoW'),
#        ('CN', 'CN', 'BE', 'DE', 'IE', 'RoW', 'GB', 'FR', 'CN', 'JP', 'DK', 'ES', 'KR', 'EE', 'SE', 'CN', 'FI', 'PL', 'NL', 'CN', 'NO', 'PT'),
#        ('RoW', 'RER'), ('RoW', 'CH', 'Europe without Switzerland', 'US'),
#        ('CA',),
#        ('CA', 'CA', 'RoW', 'RER', 'RoW', 'CA', 'RoW', 'RER', 'RER'),
#        ('CA', 'US', 'CA'), ('DE', 'RoW', 'RER w/o CH+DE', 'CH'),
#        ('RoW', 'CH', 'CA'),
#        ('AU', 'RoW', 'AU', 'RNA', 'RLA', 'RER', 'RAS', 'RER', 'RoW', 'RNA', 'RAS', 'RLA'),
#        ('Europe without Switzerland', 'RoW', 'CH'),
#        ('US', 'CH', 'ES', 'CA', 'TN', 'BR', 'IN', 'CN', 'FR', 'WA', 'RoW', 'WA', 'DE'),
#        ('US', 'FR', 'AU', 'RoW', 'AU', 'CA', 'DE', 'ES', 'CA', 'CA', 'RoW'),
#        ('RER', 'CA', 'RoW'), ('DE', 'RoW'), ('US', 'IN', 'RoW'),
#        ('CH', 'RoW', 'RoW', 'Europe without Switzerland', 'CH', 'Europe without Switzerland'),
#        ('RoW', 'CH'), ('CA', 'CA', 'CA', 'FI', 'FI', 'RoW'),
#        ('RLA', 'RoW'), ('FR', 'RoW'), ('CH',),
#        ('AU', 'AU', 'RoW', 'AU', 'RoW', 'RoW'), ('IN', 'IN', 'IN'),
#        ('US', 'RoW'), ('GLO', 'GLO', 'GLO'),
#        ('RoW', 'Europe without Switzerland', 'CH'),
#        ('Europe without Switzerland', 'CH', 'RoW'),
#        ('RoW', 'RoW', 'CH', 'CH'), ('RoW', 'DE'), ('GLO', 'GLO'),
#        ('RoW', 'CA', 'RoW', 'RoW', 'CA', 'CA'),
#        ('CA', 'RoW', 'RoW', 'CH', 'CA', 'CH'), ('RER', 'RoW', 'CA'),
#        ('RER', 'RoW', 'RER', 'RoW', 'RER', 'RoW'), ('RoW', 'WA'),
#        ('CA', 'CH'), ('CA', 'RoW', 'CH'),
#        ('RoW', 'CH', 'Europe without Switzerland'),
#        ('RoW', 'CH', 'CH', 'RoW'), ('RoW', 'RoW', 'CH', 'RoW'), ('RER',),
#        ('CH', 'Europe without Switzerland', 'RoW'),
#        ('CA', 'CA', 'RoW', 'RoW', 'RoW', 'RoW', 'CA', 'RoW', 'RoW', 'CA', 'CA'),
#        ('GLO', 'RER'), ('RoW', 'CA'), ('RER', 'GLO'),
#        ('CH', 'DK', 'AT', 'PL'), ('RoW', 'RoW', 'RER', 'RER'),
#        ('CH', 'CH', 'CH'), ('WF', 'TN'),
#        ('IAI Area, Asia, without China and GCC', 'RNA', 'UN-OCEANIA', 'IAI Area, Russia & RER w/o EU27 & EFTA', 'RoW', 'RAF', 'IAI Area, EU27 & EFTA', 'RLA', 'IAI Area, Gulf Cooperation Council', 'CN'),
#        ('Europe without Switzerland', 'CA', 'RoW'),
#        ('LT', 'WE', 'SI', 'CA', 'BG', 'RoW', 'IT', 'AT', 'LV', 'RO', 'WE', 'SE', 'FR', 'WE', 'GB', 'DK', 'HU', 'LU', 'WE', 'MT', 'WE', 'ES', 'HR', 'FI', 'WE', 'PT', 'NL', 'DE', 'WE', 'GR', 'CY', 'EE', 'NO', 'SK', 'PL', 'CH', 'CZ', 'BE', 'IE'),
#        ('RoW', 'RER', 'RoW', 'CA', 'RER', 'CA', 'RER', 'CA', 'RoW'),
#        ('WE', 'CN', 'CA', 'IN', 'US', 'RoW', 'RU'), ('RoW', 'GB'),
#        ('RoW', 'CH', 'RoW', 'RoW'), ('US', 'CA', 'CA', 'CA'),
#        ('CA', 'RoW'),
#        ('CA', 'RoW', 'RoW', 'RER', 'RoW', 'CA', 'RER', 'CA', 'RoW', 'CA', 'RER', 'RER'),
#        ('CA', 'RoW', 'CH', 'RoW', 'CA', 'CH'), ('RoW', 'US', 'FR'),
#        ('WA', 'MX', 'WF', 'ID', 'WF', 'IT', 'WF', 'WL', 'ES', 'WA', 'ZA', 'CN', 'WL', 'BR', 'US', 'TR', 'WA', 'WL', 'WA', 'FR', 'WL', 'RoW', 'BE', 'WL', 'WL', 'WL'),
#        ('RNA', 'CN', 'RER', 'IN'), ('US',), ('RoW', 'FR'),
#        ('RER', 'RoW', 'RoW', 'RER'), ('RoW', 'RER', 'CA'),
#        ('CA', 'RoW', 'RER'),
#        ('US', 'CH', 'CN', 'Europe without Switzerland', 'RoW', 'BR'),
#        ('RoW', 'RER', 'RoW', 'RoW', 'RER', 'RER'),
#        ('LU', 'CA', 'AT', 'CH', 'RoW', 'CA', 'ES', 'HU', 'TR', 'CA', 'RoW', 'AT', 'NO', 'CA', 'DK', 'HU', 'TW', 'CA', 'RU', 'SK', 'CA', 'NL', 'CA', 'DE', 'DE', 'PT', 'LU', 'CA', 'DK', 'CA', 'RoW', 'GB', 'LU', 'SE', 'CA', 'BE', 'NL', 'KR', 'NO', 'HU', 'TW', 'TW', 'CZ', 'ES', 'IT', 'SE', 'CA', 'CZ', 'TR', 'BE', 'PL', 'SK', 'FR', 'PL', 'IT', 'JP', 'KR', 'BG', 'RU', 'CA', 'CA', 'FI', 'GB', 'NO', 'CA', 'BG', 'CH', 'FR', 'PT', 'FR', 'BG', 'CH', 'CZ', 'AT', 'KR', 'IT', 'CA', 'SE', 'NL', 'CA', 'CA', 'FI', 'BE', 'FI', 'RU', 'SK', 'TR', 'DE', 'PL', 'GB', 'JP', 'CA', 'ES', 'JP', 'DK', 'PT'),
#        ('CH', 'RoW', 'Europe without Switzerland', 'CA'),
#        ('FI', 'RoW', 'EE', 'IE', 'SE', 'LT', 'RU'),
#        ('CN', 'US', 'RoW', 'FR', 'CH'), ('SE', 'RoW'),
#        ('CA', 'CA', 'RoW', 'RoW', 'CA', 'RoW'), ('RoW', 'CN', 'FR', 'WL'),
#        ('CA', 'CH', 'Europe without Switzerland', 'RoW'), ('US', 'US'),
#        ('WA', 'WA', 'WA'), ('WF',),
#        ('DK', 'FI', 'FR', 'CH', 'PL', 'DE', 'CZ', 'HU', 'ES', 'IT', 'SK', 'AT', 'BE', 'GR', 'NL', 'GB'),
#        ('BE', 'CH', 'IT', 'GB', 'ES', 'LU', 'DE'), ('US', 'ES', 'RoW'),
#        ('IT', 'CH', 'CZ', 'HU', 'DE', 'SI'), ('RoW', 'RER', 'RER', 'RoW'),
#        ('RoW', 'DK'), ('RoW', 'CA', 'RER'),
#        ('Europe without Switzerland', 'RoW'),
#        ('CH', 'CA', 'RoW', 'Europe without Switzerland'), ('RoW', 'US'),
#        ('IT', 'RoW', 'MX', 'TR', 'RU', 'US', 'CH', 'ID', 'DE', 'PT', 'AT', 'RNA', 'JP', 'WE', 'WA'),
#        ('DK', 'NL', 'SE', 'FI'),
#        ('BR', 'RO', 'US', 'US', 'US', 'SE', 'TR', 'PT', 'WE', 'GB', 'US', 'TR', 'EE', 'US', 'US', 'FR', 'LV', 'US', 'IT', 'US', 'AT', 'CZ', 'HR', 'TW', 'SE', 'CZ', 'KR', 'WE', 'IE', 'PL', 'PT', 'LT', 'FI', 'ES', 'KR', 'DE', 'PL', 'GR', 'EE', 'SK', 'AU', 'DE', 'US', 'US', 'BG', 'WE', 'BG', 'LU', 'US', 'WE', 'IE', 'US', 'LT', 'RU', 'TW', 'HR', 'GB', 'IT', 'RU', 'DK', 'LV', 'FR', 'ES', 'HU', 'AT', 'SK', 'US', 'US', 'RoW', 'US', 'DK', 'FI', 'BE', 'GR', 'NL', 'HU', 'US', 'US', 'RoW', 'SI', 'LU', 'US', 'US', 'BE', 'RO', 'SI', 'US', 'AU', 'BR', 'NL'),
#        ('WL', 'RoW'), ('CH', 'RoW', 'RoW', 'RoW'),
#        ('SK', 'ID', 'SI', 'US', 'US', 'US', 'US', 'EE', 'US', 'US', 'KR', 'IT', 'LT', 'US', 'EE', 'HU', 'AU', 'WA', 'AT', 'PL', 'US', 'BG', 'LT', 'US', 'CA', 'DE', 'BG', 'HR', 'CA', 'CA', 'LU', 'CA', 'SI', 'RoW', 'CH', 'IE', 'DK', 'TW', 'LV', 'HU', 'US', 'DK', 'GB', 'FR', 'MX', 'HR', 'DE', 'BE', 'KR', 'WA', 'FI', 'RO', 'CA', 'WL', 'US', 'CA', 'CY', 'IT', 'GR', 'AT', 'WM', 'BE', 'CA', 'NL', 'US', 'BR', 'ES', 'RoW', 'TW', 'AU', 'WL', 'BR', 'FI', 'US', 'WA', 'LV', 'PT', 'CY', 'WE', 'US', 'WM', 'WE', 'IE', 'MX', 'TR', 'ID', 'SK', 'GR', 'CA', 'WL', 'NL', 'PL', 'SE', 'US', 'NO', 'NO', 'RO', 'SE', 'TR', 'ES', 'CA', 'CA', 'PT', 'US', 'US', 'WL', 'CZ', 'CA', 'CZ', 'LU', 'CH', 'WA', 'US', 'FR', 'GB', 'CA'),
#        ('CA', 'RER', 'RoW'), ('RoW', 'CH', 'RoW', 'CH'), ('NL', 'RoW'),
#        ('NO', 'SE', 'DE'),
#        ('SE', 'NL', 'PL', 'CZ', 'DK', 'IT', 'ES', 'FR', 'AT', 'CH', 'GB', 'DE', 'BE'),
#        ('RoW', 'RER', 'RoW', 'RER'),
#        ('FR', 'WL', 'ES', 'WE', 'HU', 'MX', 'WA', 'IN', 'WA', 'CN', 'US', 'NL', 'CA', 'RU', 'IT', 'RoW', 'CH', 'AU', 'FI', 'WL', 'BR', 'DE', 'WM'),
#        ('CH', 'Europe without Switzerland', 'CA', 'RoW'),
#        ('RoW', 'CA', 'CH'), ('WF', 'RoW', 'WM'), ('ZA',),
#        ('CH', 'CA', 'RoW'), ('RoW', 'FR', 'RoW', 'FR', 'CA', 'CA'),
#        ('CA', 'RoW', 'RU'), ('RoW', 'CH', 'CH', 'RoW', 'CH', 'RoW'),
#        ('BR', 'CH', 'BR', 'RoW', 'CH', 'RoW'), ('CH', 'CH'),
#        ('RoW', 'RoW', 'RoW', 'CH'),
#        ('LU', 'BE', 'GR', 'US', 'LV', 'HR', 'RU', 'WE', 'US', 'WE', 'DK', 'DE', 'NL', 'LT', 'NO', 'US', 'FI', 'US', 'WM', 'HU', 'DE', 'US', 'WM', 'NO', 'TR', 'US', 'AT', 'RO', 'US', 'LT', 'SK', 'RoW', 'NL', 'IT', 'PL', 'LU', 'BR', 'US', 'US', 'TR', 'BR', 'WM', 'PT', 'DK', 'AT', 'US', 'GB', 'IT', 'AU', 'US', 'SK', 'US', 'BG', 'GB', 'ES', 'HU', 'ES', 'HR', 'WM', 'RU', 'US', 'PL', 'US', 'BE', 'US', 'KR', 'KR', 'AU', 'GR', 'FI', 'US', 'PT', 'RO', 'US', 'US', 'LV', 'RoW', 'BG'),
#        ('RoW', 'US', 'WF'),
#        ('US', 'GB', 'US', 'WA', 'IN', 'WM', 'AU', 'SE', 'WE', 'WL', 'WL', 'LV', 'WL', 'CA', 'WF', 'WL', 'ZA', 'WF', 'WA', 'WF', 'WE', 'WE', 'ID', 'WF', 'DE', 'WA', 'IN', 'AT', 'WF', 'WL', 'WA', 'CY', 'WE', 'WM', 'WM', 'WF', 'MT', 'CA', 'WA', 'CA', 'WL', 'WA', 'IE', 'RU', 'WM', 'CA', 'WE', 'WF', 'CA', 'WL', 'TN', 'WE', 'WM', 'WL', 'KR', 'US', 'WL', 'CN', 'WF', 'WE', 'WA', 'LT', 'WL', 'ER', 'US', 'WF', 'US', 'US', 'IN', 'IN', 'JP', 'WL', 'SK', 'WA', 'TR', 'WA', 'MX', 'BR', 'CA', 'WM', 'IT', 'WA', 'WF', 'WF', 'WL', 'US', 'WE', 'FI', 'CA', 'WF', 'WL', 'WF', 'WM', 'RoW', 'CA', 'PT', 'WM', 'WE', 'DK', 'WE', 'WL', 'SI', 'NL', 'WF', 'WL', 'WF', 'WF', 'EE', 'WF', 'RO', 'US', 'WA', 'NO', 'WM', 'WA', 'WM', 'WL', 'WA', 'BE', 'WF', 'CA', 'WM', 'WL', 'CA', 'WA', 'FR', 'HR', 'WF', 'CA', 'HU', 'WA', 'WE', 'US', 'WF', 'WA', 'WA', 'WA', 'WE', 'GR', 'US', 'PL', 'WM', 'BG', 'WE', 'WL', 'WA', 'CZ', 'WF', 'CH', 'LU', 'CA', 'WF', 'US', 'WF', 'WA', 'CA', 'ES', 'WF', 'WF', 'WF', 'WL', 'WF', 'WA', 'TW', 'WL', 'WL', 'WM', 'IN', 'WE'),
#        ('WA',),
#        ('CN', 'RER', 'RU', 'RNA', 'RoW', 'RLA', 'IN', 'ID', 'ZA', 'AU'),
#        ('MX', 'WL'), ('ID', 'CN', 'RER', 'IN', 'ZA', 'RLA'),
#        ('CH', 'RoW', 'RoW', 'CH', 'Europe without Switzerland', 'Europe without Switzerland', 'RoW', 'RoW', 'Europe without Switzerland', 'Europe without Switzerland', 'CH', 'CH', 'RoW', 'RoW', 'RoW', 'Europe without Switzerland', 'RoW', 'CH', 'RoW', 'Europe without Switzerland', 'RoW', 'CH', 'CH', 'Europe without Switzerland', 'Europe without Switzerland', 'Europe without Switzerland', 'CH', 'CH', 'Europe without Switzerland', 'RoW', 'Europe without Switzerland', 'CH'),
#        ('WA', 'US', 'RoW', 'HU'),
#        ('US', 'RoW', 'CH', 'Europe without Switzerland'),
#        ('CH', 'RoW', 'CA'), ('CA', 'RoW', 'FR', 'CH'),
#        ('RoW', 'US', 'US', 'RoW'),
#        ('SE', 'SE', 'SE', 'RoW', 'RoW', 'RoW'),
#        ('RO', 'HR', 'WE', 'WE', 'HU', 'WE', 'WE', 'WE'),
#        ('CH', 'IE', 'NL', 'BE', 'DK'), ('RoW', 'RoW', 'CH'),
#        ('ES', 'RoW', 'US', 'ZA'), ('RoW', 'WL'), ('RoW',),
#        ('CA', 'RoW', 'Europe without Switzerland'), ('RoW', 'IN', 'RER'),
#        ('CA', 'CH', 'RoW', 'Europe without Switzerland'),
#        ('RoW', 'WA', 'WL', 'CH', 'WL', 'IT', 'AU', 'NL', 'MX', 'FI', 'CN', 'WA', 'FR', 'DE', 'WE', 'HU', 'BR', 'CA', 'IN', 'WM', 'US', 'RU', 'ES'),
#        ('DE', 'DE', 'RoW', 'RoW'), ('RoW', 'BE'), ('CN', 'RoW', 'IN'),
#        ('RoW', 'Europe without Switzerland', 'CH', 'US'),
#        ('WA', 'CN', 'IN', 'RoW', 'NL'), ('WL',), ('CA', 'CA', 'CA', 'CA'),
#        ('TR', 'WE', 'WE'), ('GR', 'WE'),
#        ('KR', 'JP', 'CN', 'CN', 'RO', 'ES', 'SK', 'RoW', 'CN', 'CZ', 'FI', 'CN', 'CN', 'WM', 'BG', 'CN', 'CN', 'CN', 'AT', 'CA', 'US', 'DE', 'WE', 'PL', 'CN', 'CA', 'MX', 'CN', 'CN', 'WL', 'IE', 'CN', 'BE', 'CA', 'HR', 'BR', 'CA', 'GB', 'CY', 'LV', 'CA', 'SE', 'CA', 'US', 'CN', 'CA', 'CN', 'US', 'CN', 'IT', 'CA', 'ZA', 'LU', 'GR', 'CN', 'ID', 'RU', 'LT', 'CN', 'CN', 'CN', 'EE', 'PT', 'WL', 'CN', 'CN', 'TW', 'CN', 'AU', 'CA', 'US', 'CH', 'CN', 'NO', 'US', 'CN', 'CN', 'US', 'CN', 'CN', 'TR', 'US', 'HU', 'US', 'CA', 'CA', 'US', 'CA', 'NL', 'CN', 'CN', 'FR', 'CN', 'DK'),
#        ('RU', 'AT', 'RoW', 'FI', 'LU', 'BG', 'CA', 'KR', 'SK', 'DE', 'CA', 'CA', 'IT', 'CA', 'NO', 'GR', 'CZ', 'ES', 'DK', 'IE', 'SI', 'HU', 'CH', 'TW', 'NL', 'BE', 'PL', 'WA', 'WE', 'JP', 'ID', 'GB', 'SE', 'CA', 'PT', 'WE', 'TR', 'FR'),
#        ('IT', 'ES', 'RoW'), ('WA', 'RoW'),
#        ('RoW', 'RoW', 'RoW', 'WA', 'WA', 'WA'),
#        ('CA', 'RoW', 'CA', 'RoW'), ('CN', 'RoW'),
#        ('Europe without Switzerland', 'CH', 'CA', 'RoW'),
#        ('GLO', 'GLO', 'GLO', 'GLO'),
#        ('GLO', 'CA', 'Europe without Switzerland'), ('RoW', 'BR', 'US'),
#        ('CN',), ('IN', 'IN', 'IN', 'IN'), ('FR', 'IT', 'TR', 'RoW', 'ES'),
#        ('RER w/o CH+DE', 'RoW', 'CH', 'DE'),
#        ('CA', 'RoW', 'CH', 'CH', 'CA', 'RoW'),
#        ('RLA', 'ZA', 'ID', 'CN', 'RER', 'RNA'),
#        ('RNA', 'RER', 'RLA', 'CN'), ('WE', 'RU', 'LV'),
#        ('RER', 'RER', 'RoW', 'RoW'),
#        ('RAF', 'GLO', 'CN', 'RER', 'US', 'WM', 'RNA', 'Europe without Switzerland', 'CA', 'UCTE', 'RER', 'RAS', 'CA', 'IN', 'RLA'),
#        ('CA', 'CH', 'RoW'),
#        ('IE', 'CN', 'CN', 'CA', 'IN', 'CN', 'IN', 'CA', 'IN', 'AU', 'HR', 'US', 'BE', 'US', 'LT', 'RU', 'FR', 'WE', 'CN', 'RO', 'CH', 'US', 'CA', 'PT', 'CA', 'WE', 'WE', 'KR', 'CZ', 'CN', 'CA', 'US', 'ZA', 'CN', 'LU', 'RoW', 'US', 'CA', 'IT', 'SE', 'CA', 'CN', 'SI', 'US', 'CN', 'GB', 'AT', 'JP', 'CN', 'DE', 'CN', 'US', 'CN', 'CA', 'US', 'BG', 'TW', 'US', 'IN', 'NO', 'ES', 'IN', 'CA', 'CN', 'GR', 'PL', 'SK', 'US', 'IN'),
#        ('IN',), ('WL', 'WL', 'WA'),
#        ('IN', 'CN', 'CA', 'CA', 'WA', 'CN', 'CN', 'HR', 'FR', 'TR', 'CN', 'RER', 'CN', 'CN', 'CA', 'GR', 'RO', 'NL', 'IN', 'IN', 'CN', 'SI', 'CA', 'LV', 'CA', 'NO', 'US', 'PT', 'CN', 'LT', 'CN', 'BR', 'CZ', 'CA', 'BG', 'CA', 'MX', 'BE', 'US', 'CN', 'US', 'LU', 'WE', 'MT', 'US', 'CN', 'US', 'CN', 'HU', 'WF', 'CN', 'AU', 'CN', 'CN', 'US', 'RU', 'US', 'WL', 'WE', 'CN', 'WE', 'IN', 'GB', 'CN', 'TW', 'CN', 'WE', 'ES', 'CN', 'NORDEL', 'CN', 'CA', 'WE', 'ZA', 'CN', 'CN', 'CN', 'US', 'SK', 'ID', 'CN', 'CN', 'CH', 'CA', 'IN', 'DE', 'FI', 'US', 'SE', 'CA', 'CY', 'CN', 'DK', 'US', 'JP', 'WL', 'CN', 'CN', 'KR', 'WM', 'EE', 'CN', 'CA', 'PL', 'AT', 'US', 'CN', 'WA', 'WM', 'IE', 'CN', 'CA', 'CN', 'CA', 'IT'),
#        ('WL', 'RoW', 'WL', 'RoW'),
#        ('RLA', 'AU', 'RNA', 'RoW', 'ID', 'RU', 'CN', 'RER'),
#        ('ES', 'RoW', 'ZA', 'AU', 'US'), ('DE',),
#        ('CH', 'RoW', 'Europe without Switzerland', 'RoW', 'CH', 'Europe without Switzerland'),
#        ('RoW', 'IN'), ('LT',), ('US', 'US', 'RoW', 'RoW'),
#        ('FI', 'SE', 'WE', 'WE', 'WL', 'DK', 'WL', 'GB', 'NO', 'BE', 'BR', 'LV', 'IE', 'NL', 'MT', 'SI', 'ZA', 'IT', 'SK', 'CY', 'WE', 'BG', 'RO', 'WE', 'ES', 'AT', 'PT', 'HU', 'EE', 'WE', 'LU', 'GR', 'FR', 'RoW', 'WE', 'CZ', 'HR', 'CH', 'WE', 'LT', 'DE', 'PL', 'IN'),
#        ('CH', 'CH', 'CH', 'CH'), ('RoW', 'RNA'),
#        ('IT', 'BE', 'FR', 'DE', 'AT'), ('FR', 'AT', 'CH', 'SI', 'GR'),
#        ('CA', 'Europe without Switzerland', 'RoW'),
#        ('FR', 'CN', 'BR', 'IN', 'WA', 'RoW', 'CA', 'US', 'DE', 'WA', 'ES', 'TN', 'CH'),
#        ('IN', 'RER', 'RoW'), ('NO', 'RoW'),
#        ('CH', 'RoW', 'RoW', 'RoW', 'CH', 'CH'),
#        ('ES', 'SI', 'DE', 'SK', 'PL', 'RoW', 'HU', 'AT', 'GR', 'WE', 'FR', 'CZ', 'WE'),
#        ('RoW', 'UCTE'), ('RoW', 'WL', 'WL', 'RoW'),
#        ('CH', 'RoW', 'CA', 'CH', 'CA', 'RoW'), ('CH', 'RoW', 'RoW', 'CH'),
#        ('PL', 'IT', 'AT', 'DK', 'DE', 'BE', 'GB', 'CH', 'FR'),
#        ('WL', 'RoW', 'US', 'IT', 'CN'),
#        ('SE', 'SE', 'RoW', 'SE', 'RoW', 'SE', 'RoW', 'RoW', 'SE', 'RoW'),
#        ('ES', 'AT', 'CY', 'NL', 'GR', 'WL', 'BG', 'WE', 'IT', 'SK', 'LT', 'IN', 'RoW', 'HR', 'NO', 'GB', 'PT', 'RO', 'ZA', 'FR', 'BR', 'CZ', 'SE', 'BE', 'DE', 'WE', 'LU', 'PL', 'WE', 'WE', 'WL', 'IE', 'FI', 'WE', 'LV', 'WE', 'HU', 'CH', 'MT', 'WE', 'DK', 'EE', 'SI'),
#        ('RNA', 'IAI Area, EU27 & EFTA', 'CN', 'RAF', 'IAI Area, Asia, without China and GCC', 'IAI Area, Russia & RER w/o EU27 & EFTA', 'RLA', 'UN-OCEANIA'),
#        ('ZA', 'RoW'),
#        ('RoW', 'Europe without Switzerland', 'Europe without Switzerland', 'RoW', 'CH', 'CH'),
#        ('RER', 'Europe without Switzerland'),
#        ('CA', 'RER', 'RoW', 'RER', 'CA', 'RoW'),
#        ('RAF', 'IAI Area, Gulf Cooperation Council', 'RLA', 'IAI Area, EU27 & EFTA', 'IAI Area, Russia & RER w/o EU27 & EFTA', 'CN', 'UN-OCEANIA', 'IAI Area, Asia, without China and GCC', 'RNA'),
#        ('CH', 'US', 'Europe without Switzerland', 'RoW'),
#        ('IN', 'RoW', 'IN', 'RoW'), ('RoW', 'FR', 'US'),
#        ('RoW', 'IN', 'ID', 'BR', 'WA'),
#        ('RoW', 'CH', 'CA', 'Europe without Switzerland'),
#        ('IAI Area, Asia, without China and GCC', 'IAI Area, Russia & RER w/o EU27 & EFTA', 'IAI Area, EU27 & EFTA', 'RNA', 'RLA'),
#        ('CA', 'CA', 'CA', 'RoW', 'CA'),
#        ('Europe without Switzerland', 'CA', 'RoW', 'CH'),
#        ('IAI Area, EU27 & EFTA', 'RoW'), ('TR', 'WE', 'WE', 'GR', 'RO'),
#        ('RoW', 'CA', 'RoW', 'CA'), ('DE', 'ES', 'RoW', 'FR'),
#        ('CH', 'CA', 'RoW', 'CA', 'RoW', 'CH'), ('RoW', 'CN', 'RoW', 'CN'),
#        ('BR',), ('RoW', 'DE', 'RoW', 'RoW', 'DE', 'RoW', 'DE', 'DE'),
#        ('RoW', 'RoW', 'RER', 'RER', 'RoW', 'RER'), ('LT', 'EE'),
#        ('CA', 'CA', 'RoW', 'RoW'), ('WEU', 'RoW'),
#        ('WA', 'WL', 'RoW', 'WF', 'WL', 'WA', 'WL', 'WA', 'WF', 'BR', 'WL', 'WF', 'ID'),
#        ('RoW', 'ES', 'MX', 'TR'), ('TR', 'RoW'), ('IE', 'NL', 'FR'),
#        ('RoW', 'Europe without Switzerland', 'CH', 'RoW', 'Europe without Switzerland', 'CH'),
#        ('RoW', 'NORDEL'), ('HR', 'IT', 'AT'),
#        ('CH', 'US', 'RoW', 'Europe without Switzerland'),
#        ('RoW', 'US', 'CN'),
#        ('RoW', 'Europe without Switzerland', 'CH', 'CH', 'RoW', 'Europe without Switzerland', 'Europe without Switzerland', 'RoW'),
#        ('CH', 'CA'), ('BR', 'BR', 'RoW', 'BR', 'RoW', 'RoW', 'RoW', 'BR'),
#        ('WL', 'ID', 'RoW', 'WA'), ('IN', 'WA', 'IN', 'IN', 'IN'),
#        ('US', 'RoW', 'WL', 'CA'),
#        ('SI', 'WL', 'MT', 'RO', 'IT', 'PT', 'LV', 'GR', 'WE', 'SK', 'WL', 'DK', 'FR', 'ES', 'HU', 'IN', 'RoW', 'WE', 'AT', 'WE', 'SE', 'IE', 'GB', 'DE', 'CZ', 'NO', 'WE', 'WE', 'BE', 'FI', 'WE', 'NL', 'BR', 'EE', 'LT', 'ZA', 'CH', 'LU', 'PL', 'CY', 'HR', 'WE', 'BG'),
#        ('RoW', 'CN', 'CH'),
#        ('DE', 'DE', 'RoW', 'DE', 'DE', 'RoW', 'RoW', 'RoW'),
#        ('US', 'RoW', 'US', 'RoW', 'WF', 'WF'), ('RoW', 'DE', 'CA'),
#        ('IN', 'RoW'),
#        ('RER', 'RoW', 'CA', 'CA', 'RoW', 'RER', 'RoW', 'RER'),
#        ('BE', 'NO', 'GB', 'DE'), ('RER', 'RoW', 'RER', 'RoW'),
#        ('RoW', 'RER', 'RER', 'RER', 'RoW', 'RoW'), ('RoW', 'WEU'),
#        ('RoW', 'NO', 'HU', 'NL', 'PL', 'CA', 'IE', 'FR', 'GR', 'US', 'WF', 'JP', 'RU', 'ES', 'SK', 'DE', 'SE', 'CZ', 'CH', 'CA', 'IT', 'BE', 'DK', 'AT', 'GB', 'FI'),
#        ('US', 'CA', 'US', 'WE', 'CA', 'CA', 'US', 'RoW', 'PT', 'RU', 'CA', 'CA', 'CA', 'SK', 'DE', 'ES', 'SE', 'TR', 'CA', 'FI', 'CA', 'CA', 'US', 'ZA', 'CZ', 'KR', 'WF'),
#        ('NL', 'DE', 'GB', 'RoW', 'RU'), ('TR',),
#        ('RoW', 'RoW', 'WL', 'WL'), ('RoW', 'RoW', 'US', 'US'),
#        ('US', 'CA', 'CA', 'RAS', 'WM', 'CN', 'RLA', 'RNA', 'RER', 'IN', 'RER', 'GLO', 'UCTE', 'Europe without Switzerland', 'RAF'),
#        ('WF', 'RoW'), ('RoW', 'RER', 'RER', 'RoW', 'RoW', 'RER'),
#        ('RoW', 'Europe without Switzerland'),
#        ('NL', 'RU', 'GB', 'DE', 'RoW'), ('ES', 'US', 'RoW'),
#        ('RoW', 'CH', 'FR', 'DE', 'CN', 'US'),
#        ('Europe without Switzerland', 'US', 'RoW', 'CH'), ('WL', 'BR'),
#        ('GR', 'BG', 'WM'),
#        ('US', 'CH', 'Europe without Switzerland', 'RoW'),
#        ('RoW', 'CN', 'CN', 'RoW', 'CN', 'RoW'), ('MX', 'RoW'),
#        ('CA', 'RoW', 'CH', 'CA', 'RoW', 'CH'),
#        ('FR', 'RU', 'RoW', 'WE', 'ES', 'HU'), ('RoW', 'CN'),
#        ('CH', 'CH', 'RoW', 'RoW'),
#        ('CH', 'RoW', 'CH', 'Europe without Switzerland', 'RoW', 'Europe without Switzerland'),
#        ('NL', 'IN', 'IN', 'CN', 'CN', 'US', 'IT', 'GB', 'US', 'CN', 'ES', 'WA', 'US', 'IN', 'BE', 'CN', 'CN', 'CN', 'CA', 'RU', 'PT', 'IN', 'TR', 'CN', 'FI', 'WA', 'US', 'BR', 'IN', 'HR', 'IN', 'KR', 'IE', 'IN', 'CN', 'IN', 'TW', 'CN', 'IN', 'CZ', 'IN', 'BG', 'FR', 'US', 'IN', 'MX', 'LV', 'CN', 'AT', 'CA', 'CN', 'WL', 'CN', 'US', 'CN', 'CN', 'CN', 'CN', 'CN', 'WF', 'EE', 'AU', 'JP', 'CA', 'CN', 'CN', 'US', 'CN', 'DE', 'IN', 'CN', 'CN', 'IN', 'CN', 'CN', 'CN', 'CN', 'US', 'US', 'IN', 'CN', 'RoW', 'CN', 'WL', 'CN', 'IN', 'WE', 'CA', 'US', 'CN', 'CA', 'CA', 'CN', 'IN'),
#        ('AT', 'DE', 'SK', 'PL'),
#        ('WL', 'WL', 'WL', 'WF', 'WA', 'WA', 'WF', 'WA', 'WL', 'ID', 'WF', 'BR', 'RoW'),
#        ('DK', 'PL', 'DE', 'NO', 'FI'),
#        ('Europe without Switzerland', 'RoW', 'CA'),
#        ('IAI Area, EU27 & EFTA', 'UN-OCEANIA', 'IAI Area, Gulf Cooperation Council'),
#        ('Europe without Switzerland', 'RoW', 'CH', 'CH', 'RoW', 'Europe without Switzerland'),
#        ('NL', 'NL', 'RoW', 'RoW', 'GB', 'GB', 'NO', 'NO'),
#        ('SE', 'SE', 'RoW', 'RoW', 'RoW', 'SE'),
#        ('WE', 'GR', 'GR', 'AU', 'TR', 'RoW', 'PL', 'RO', 'DE', 'WE', 'DE', 'AU', 'RoW', 'WE', 'CZ', 'PL', 'SI', 'HU', 'RO', 'WE', 'SK', 'BG', 'RU', 'SI', 'SK', 'HU', 'RU', 'CZ', 'TR', 'BG'),
#        ('RoW', 'RoW', 'RoW', 'Europe without Switzerland', 'Europe without Switzerland', 'CH', 'Europe without Switzerland'),
#        ('US', 'CN', 'RoW'),
#        ('WA', 'WA', 'WL', 'WE', 'WA', 'SK', 'WM', 'CA', 'JP', 'WF', 'LU', 'WE', 'LV', 'US', 'US', 'WM', 'WL', 'WF', 'RO', 'WF', 'WF', 'CA', 'IN', 'WE', 'WL', 'CA', 'NL', 'MT', 'WF', 'IN', 'BE', 'BG', 'WA', 'WF', 'WL', 'LT', 'US', 'KR', 'US', 'WE', 'DE', 'WF', 'WA', 'WE', 'WL', 'WM', 'WA', 'TW', 'WF', 'WM', 'WA', 'WF', 'NO', 'WL', 'WL', 'WF', 'WA', 'WM', 'WM', 'WF', 'CA', 'ES', 'RU', 'RoW', 'WL', 'WL', 'HR', 'CA', 'WA', 'CA', 'WL', 'WE', 'CN', 'US', 'SE', 'WL', 'SI', 'CY', 'WF', 'WF', 'WE', 'WE', 'CZ', 'ER', 'US', 'WA', 'ZA', 'BR', 'WA', 'WA', 'TN', 'IT', 'WE', 'WM', 'CA', 'WA', 'WF', 'CA', 'WL', 'US', 'CA', 'MX', 'WE', 'IN', 'IN', 'TR', 'WA', 'WF', 'WL', 'AT', 'WL', 'IE', 'WM', 'WF', 'ID', 'WF', 'WL', 'WM', 'WF', 'WM', 'HU', 'WA', 'WF', 'WL', 'WE', 'WA', 'CH', 'WE', 'WF', 'US', 'CA', 'WM', 'US', 'GB', 'DK', 'WA', 'WF', 'WL', 'WM', 'EE', 'WL', 'WF', 'WF', 'WA', 'CA', 'WF', 'FR', 'WF', 'CA', 'FI', 'WL', 'WF', 'WL', 'AU', 'WF', 'WA', 'WE', 'CA', 'PT', 'PL', 'WL', 'WA', 'WE', 'WM', 'IN', 'GR', 'US', 'WA', 'US'),
#        ('RLA', 'RLA', 'RoW', 'RoW', 'RoW', 'RLA'),
#        ('CA', 'FR', 'CA', 'NO', 'US', 'US', 'HR', 'CH', 'PT', 'BE', 'CN', 'BG', 'SE', 'US', 'CA', 'US', 'DE', 'US', 'NL', 'CN', 'US', 'US', 'RoW', 'ES', 'GR', 'SI', 'AU', 'CN', 'CA', 'BG', 'US', 'IT', 'CY', 'AT', 'RO', 'GR', 'FR', 'CA', 'HU', 'BE', 'CA', 'SE', 'FI', 'EE', 'US', 'BR', 'US', 'CN', 'SK', 'CA', 'NO', 'US', 'CZ', 'IE', 'PT', 'IE', 'GB', 'US', 'ZA', 'WL', 'ZA', 'FI', 'LV', 'DK', 'PL', 'IN', 'RoW', 'MT', 'SK', 'DK', 'SI', 'CA', 'IT', 'US', 'NL', 'CA', 'BR', 'US', 'US', 'CA', 'JP', 'CA', 'EE', 'LV', 'HU', 'MT', 'CA', 'AT', 'WL', 'RU', 'IN', 'PL', 'RU', 'AU', 'CY', 'HR', 'RO', 'US', 'US', 'KR', 'LU', 'KR', 'CZ', 'LU', 'JP', 'US', 'US', 'CH', 'GB', 'DE', 'ES', 'US'),
#        ('RoW', 'IN', 'BR'), ('SE', 'RoW', 'RoW', 'SE'),
#        ('RO', 'HR', 'WE', 'AT', 'WE'),
#        ('RLA', 'UN-OCEANIA', 'IAI Area, Asia, without China and GCC', 'CN', 'IAI Area, EU27 & EFTA', 'RNA', 'IAI Area, Gulf Cooperation Council', 'RoW', 'IAI Area, Russia & RER w/o EU27 & EFTA', 'RAF'),
#        ('WE', 'EE', 'IN', 'RoW', 'MT', 'CZ', 'DK', 'NL', 'WE', 'LT', 'BE', 'WL', 'SE', 'WE', 'BR', 'NO', 'FR', 'WE', 'CY', 'HU', 'AT', 'PT', 'WE', 'LV', 'WL', 'LU', 'WE', 'ES', 'IE', 'GR', 'WE', 'SK', 'DE', 'SI', 'HR', 'GB', 'RO', 'ZA', 'PL', 'FI', 'CH', 'BG', 'IT'),
#        ('IAI Area, EU27 & EFTA',),
#        ('HU', 'CN', 'SE', 'US', 'JP', 'RoW', 'RO', 'LV', 'WM', 'US', 'US', 'SK', 'WE', 'US', 'BE', 'CH', 'DE', 'NL', 'BR', 'RU', 'FR', 'IN', 'ZA', 'US', 'CN', 'ES', 'CZ', 'FI', 'US', 'BG', 'KR', 'US', 'LT', 'CN', 'CN', 'GB', 'SI', 'US', 'TW'),
#        ('IT', 'NL', 'GR', 'PL', 'FR', 'ES', 'CH', 'GB'),
#        ('CN', 'Europe without Switzerland', 'CH', 'RoW'),
#        ('WL', 'CH', 'NL', 'MX', 'HU', 'BR', 'RoW', 'IT', 'ES', 'WL', 'US', 'CN', 'AU', 'DE', 'WE', 'CA', 'FI', 'WM', 'WA', 'FR', 'WA', 'RU'),
#        ('AU', 'RoW', 'IN'),
#        ('RoW', 'CN', 'RoW', 'CN', 'CN', 'RoW', 'RoW', 'RoW', 'CN', 'CN'),
#        ('RoW', 'RER', 'RoW', 'RER', 'RoW', 'RER'),
#        ('RER', 'RoW', 'RoW', 'RER', 'RoW', 'RER', 'RoW', 'RER'),
#        ('BR', 'RoW'),
#        ('CN', 'CN', 'IN', 'CN', 'CN', 'LV', 'CN', 'LU', 'CN', 'CN', 'GR', 'BR', 'CH', 'KR', 'TR', 'US', 'US', 'ID', 'SE', 'IN', 'FI', 'PT', 'IN', 'IN', 'WE', 'IN', 'AU', 'CN', 'SK', 'CA', 'CN', 'CA', 'CN', 'HU', 'BE', 'IN', 'WA', 'US', 'CN', 'CN', 'CN', 'CN', 'CN', 'WL', 'BG', 'NO', 'CN', 'WM', 'CN', 'CA', 'PL', 'IN', 'NL', 'CN', 'CN', 'RO', 'TW', 'US', 'WM', 'CA', 'US', 'US', 'WA', 'IN', 'US', 'CA', 'IE', 'FR', 'SI', 'CA', 'IN', 'CZ', 'IT', 'CN', 'IN', 'CN', 'CN', 'US', 'JP', 'CN', 'CN', 'CN', 'ES', 'GB', 'CY', 'CN', 'RU', 'HR', 'AT', 'CN', 'IN', 'US', 'DE', 'IN', 'MT', 'CN', 'ZA', 'CA', 'IN', 'WL', 'CA', 'MX', 'CN', 'CN', 'CN', 'RoW'),
#        ('RoW', 'CN', 'Europe without Switzerland', 'CH', 'US'),
#        ('NORDEL', 'RoW'), ('RoW', 'RU', 'DE', 'GB', 'NL'),
#        ('RoW', 'US', 'WL', 'BR', 'CH', 'CA'),
#        ('UN-OCEANIA', 'CN', 'IAI Area, Asia, without China and GCC', 'RNA', 'IAI Area, Russia & RER w/o EU27 & EFTA', 'IAI Area, EU27 & EFTA', 'RAF'),
#        ('WE', 'FR', 'LV', 'IT', 'BG', 'NL', 'LT', 'WE', 'GB', 'CY', 'SI', 'WE', 'WE', 'FI', 'WE', 'PL', 'BR', 'EE', 'CH', 'RoW', 'HU', 'GR', 'CZ', 'SE', 'WL', 'MT', 'RO', 'PT', 'SK', 'BE', 'WE', 'IN', 'IE', 'ZA', 'HR', 'LU', 'WE', 'DE', 'NO', 'WL', 'AT', 'ES', 'DK'),
#        ('RoW', 'US', 'CH', 'Europe without Switzerland'), ('BR', 'BR'),
#        ('BE', 'CN', 'RoW', 'WL'), ('BG', 'WE', 'WE', 'IT', 'TR'),
#        ('ZA', 'US', 'RoW', 'US', 'ES'), ('WF', 'RoW', 'CN', 'WA'),
#        ('WM',), ('RoW', 'Europe without Switzerland', 'CA'),
#        ('WL', 'WL', 'RoW', 'BR', 'IN'),
#        ('ES', 'TW', 'PL', 'NO', 'SK', 'RoW', 'DE', 'CA', 'FI', 'CA', 'BG', 'CH', 'TR', 'CZ', 'IT', 'PT', 'SE', 'RU', 'GB', 'CA', 'CA', 'LU', 'AT', 'JP', 'FR', 'CA', 'KR', 'HU', 'NL', 'DK', 'BE'),
#        ('CH', 'Europe without Switzerland', 'US', 'RoW'),
#        ('CN', 'RU', 'GB', 'NL', 'DE'),
#        ('RoW', 'CA', 'Europe without Switzerland', 'CH'),
#        ('CH', 'RoW', 'Europe without Switzerland', 'US'),
#        ('MX', 'ES', 'RoW', 'IT'), ('CH', 'RoW', 'CH', 'RoW'),
#        ('CH', 'CH', 'CA', 'CH', 'RoW', 'CH', 'CA', 'RoW', 'CA', 'RoW', 'RoW', 'CA'),
#        ('GLO', 'RLA', 'CA', 'Europe without Switzerland', 'RAF', 'RER', 'WM', 'RER', 'CN', 'RAS', 'UCTE', 'RNA', 'IN', 'CA', 'US'),
#        ('RoW', 'CA', 'ZA', 'WF', 'US', 'AU'),
#        ('RoW', 'RoW', 'CA', 'RoW', 'Europe without Switzerland', 'CA', 'Europe without Switzerland', 'Europe without Switzerland', 'CA'),
#        ('CN', 'RoW', 'US', 'CN', 'US', 'RoW'), ('GB',), ('RoW', 'SE'),
#        ('IT', 'AU', 'FI', 'CA', 'CN', 'WM', 'CH', 'MX', 'WL', 'RoW', 'WA', 'BR', 'WL', 'US', 'NL', 'FR', 'HU', 'ES', 'IN', 'WA', 'DE', 'WE', 'RU'),
#        ('CN', 'US', 'Europe without Switzerland', 'RoW'),
#        ('US', 'RoW', 'CN'),
#        ('RoW', 'Europe without Switzerland', 'RoW', 'Europe without Switzerland', 'CH', 'RoW', 'Europe without Switzerland'),
#        ('CH', 'US', 'Europe without Switzerland', 'RoW', 'CA'),
#        ('RoW', 'NO'), ('CA', 'CA'), ('WF', 'WF'), ('CA', 'US'),
#        ('RoW', 'RNA', 'RAS', 'AU', 'RLA', 'RER'), ('ID',),
#        ('IAI Area, EU27 & EFTA', 'RNA', 'RLA', 'IAI Area, Gulf Cooperation Council'),
#        ('GB', 'US', 'US', 'US', 'IN', 'FI', 'DE', 'SE', 'US', 'ES', 'JP', 'RoW', 'US', 'MX', 'TW', 'US', 'US', 'RU', 'US', 'CH'),
#        ('SI', 'WE', 'HU', 'WE'), ('SE', 'RoW', 'SE', 'RoW', 'CH', 'CH'),
#        ('RoW', 'RLA'), ('RoW', 'JP', 'RER'), ('CN', 'WM', 'RoW', 'NL'),
#        ('DE', 'US'), ('RoW', 'WA', 'WA', 'RoW'),
#        ('Europe without Switzerland', 'RER'),
#        ('CA', 'IT', 'CN', 'AU', 'SE', 'CA', 'CN', 'GB', 'ES', 'CA', 'CN', 'CA', 'CN', 'MX', 'CA', 'US', 'CN', 'CN', 'AT', 'CA', 'CN', 'DE', 'CN', 'CN', 'CN', 'US', 'CA', 'US', 'PT', 'RoW', 'US', 'CA', 'NL', 'CN', 'CA', 'CN', 'CN', 'CN', 'CN', 'US', 'CN', 'CN', 'JP', 'KR', 'US', 'CN', 'CN', 'CA', 'CA', 'FR', 'CN', 'BE', 'CN', 'CN', 'CA', 'CN'),
#        ('NO', 'SE', 'EE'), ('WL', 'BE', 'IN', 'WL', 'WF', 'ID', 'RoW'),
#        ('RoW', 'CA', 'US', 'RoW', 'Europe without Switzerland', 'Europe without Switzerland', 'Europe without Switzerland', 'CH', 'CH', 'US', 'Europe without Switzerland', 'Europe without Switzerland', 'US', 'RoW', 'RoW', 'Europe without Switzerland', 'US', 'Europe without Switzerland', 'Europe without Switzerland', 'US', 'CH', 'RoW', 'Europe without Switzerland', 'CH', 'CH', 'US', 'US', 'US', 'RoW', 'CH', 'CH', 'US', 'CH', 'RoW', 'US', 'RoW', 'RoW', 'Europe without Switzerland', 'US', 'CH', 'RoW', 'CH', 'Europe without Switzerland', 'RoW', 'CH'),
#        ('DE', 'IT', 'RoW', 'FR'), ('MX',),
#        ('Europe without Switzerland', 'CH', 'RoW', 'Europe without Switzerland', 'CA', 'RoW'),
#        ('CH', 'CH', 'RoW', 'RoW', 'RoW', 'CH'),
#        ('CA', 'CA', 'RoW', 'CH', 'CH', 'CH', 'RoW', 'CA', 'RoW', 'CA', 'CH', 'RoW'),
#        ('RoW', 'CH', 'Europe without Switzerland', 'CA'),
#        ('WE', 'BG', 'SK', 'IN', 'WE', 'EE', 'HU', 'LV', 'WE', 'HR', 'FI', 'GB', 'BR', 'BE', 'WE', 'RoW', 'RO', 'CZ', 'AT', 'SI', 'DK', 'WE', 'DE', 'PT', 'GR', 'IT', 'SE', 'LT', 'PL', 'LU', 'NL', 'ES', 'NO', 'MT', 'IE', 'WL', 'ZA', 'FR', 'CY', 'WE', 'WL', 'CH', 'WE'),
#        ('WE', 'WE', 'SK', 'CH', 'ES', 'NO', 'WE', 'GB', 'AT', 'CZ', 'ZA', 'SI', 'FR', 'WL', 'LV', 'CY', 'NL', 'WE', 'WE', 'FI', 'RO', 'LT', 'IN', 'PL', 'HU', 'IT', 'WE', 'RoW', 'BG', 'SE', 'LU', 'BR', 'DE', 'GR', 'WL', 'EE', 'HR', 'WE', 'BE', 'PT', 'MT', 'DK', 'IE'),
#        ('PT', 'FR'), ('ID', 'RoW', 'WA', 'BR', 'WA'), ('NO', 'WF'),
#        ('IN', 'IN', 'CH', 'US', 'IN', 'WE', 'CA', 'IN', 'JP', 'RoW', 'IN', 'HR', 'IN', 'IN', 'IN', 'NO', 'IN', 'WE', 'IN', 'US', 'US', 'IN', 'IN', 'FR', 'CA', 'IN', 'IN', 'US', 'US', 'LV', 'IN', 'WL', 'IN', 'IN', 'IT', 'IN', 'AT', 'WL', 'CA', 'WE', 'IN', 'IN', 'CA', 'US'),
#        ('RER', 'RoW', 'RoW', 'RoW', 'RER', 'RER'),
#        ('US', 'LT', 'WE', 'CA', 'LV', 'IT', 'US', 'CA', 'RU', 'AT', 'WL', 'US', 'BR', 'PL', 'WM', 'CA', 'TW', 'BR', 'US', 'RU', 'DE', 'FR', 'CZ', 'DE', 'US', 'CA', 'LT', 'TW', 'WE', 'US', 'CA', 'GB', 'CA', 'RO', 'US', 'LV', 'PT', 'US', 'US', 'SI', 'WE', 'CA', 'US', 'FI', 'ES', 'CA', 'KR', 'CA', 'GB', 'AT', 'CA', 'WL', 'US', 'CA', 'HU', 'AU', 'CA', 'GR', 'CA', 'NO', 'BE', 'RoW', 'CZ', 'RO', 'IE', 'US', 'BG', 'GR', 'WE', 'SK', 'US', 'SE', 'SE', 'CA', 'NL', 'BG', 'HR', 'WE', 'TR', 'CA', 'WE', 'EE', 'FI', 'CA', 'ES', 'KR', 'LU', 'DK', 'LU', 'WM', 'TR', 'HR', 'HU', 'WM', 'US', 'SI', 'WE', 'AU', 'PL', 'PT', 'IT', 'NO', 'CA', 'CA', 'CA', 'US', 'WM', 'EE', 'BE', 'SK', 'CA', 'NL', 'IE', 'FR', 'US', 'DK', 'WE', 'RoW', 'US', 'US'),
#        ('CA', 'Europe without Switzerland', 'RoW', 'CH'),
#        ('CA', 'CA', 'CA'), ('FI', 'WE', 'EE', 'LT', 'WE', 'LV', 'NO'),
#        ('WF', 'US', 'US', 'NL', 'WF', 'CA', 'NL', 'CA', 'RoW', 'RoW'),
#        ('CN', 'RoW', 'US'), ('RER w/o CH+DE', 'RoW', 'DE', 'CH'),
#        ('RoW', 'RNA', 'RNA', 'RER', 'RoW', 'RER', 'RNA', 'RoW', 'RER', 'RNA', 'CN', 'RoW', 'RER', 'CN', 'RNA', 'RoW', 'CN', 'CN', 'CN', 'CN', 'CN', 'CN', 'RER', 'RER', 'RNA', 'RoW', 'RoW', 'RER', 'RoW'),
#        ('RER', 'RoW', 'RER', 'RER', 'RoW', 'RoW', 'RoW', 'RER'),
#        ('GLO', 'GLO', 'GLO', 'GLO', 'GLO'),
#        ('RoW', 'RER', 'RER', 'RoW', 'RoW', 'CA', 'RER'),
#        ('RoW', 'CH', 'DE', 'US'), ('CH', 'RoW', 'CH', 'RoW', 'RoW', 'CH'),
#        ('RoW', 'RER', 'RER', 'RoW', 'RER', 'RoW'),
#        ('Europe without Switzerland', 'RoW', 'CH', 'CH', 'Europe without Switzerland', 'RoW'),
#        ('RoW', 'IN', 'IN', 'RoW'),
#        ('RNA', 'IAI Area, EU27 & EFTA', 'IAI Area, Russia & RER w/o EU27 & EFTA', 'IAI Area, Asia, without China and GCC', 'CN', 'RLA', 'UN-OCEANIA'),
#        ('WM', 'WM'),
#        ('CH', 'RU', 'DK', 'JP', 'KR', 'AT', 'DE', 'FR', 'NO', 'HU', 'SK', 'PT', 'GB', 'SE', 'FI', 'RoW', 'BE', 'BG', 'NL', 'IT', 'PL', 'CZ', 'TW', 'ES', 'LU', 'TR'),
#        ('RU', 'WM', 'RoW', 'RAF'),
#        ('FI', 'AT', 'TW', 'KR', 'PL', 'FI', 'BG', 'SE', 'NL', 'DE', 'WE', 'TR', 'SK', 'NO', 'RoW', 'NL', 'IT', 'RU', 'DK', 'RU', 'PL', 'DE', 'CZ', 'NO', 'TW', 'SK', 'CZ', 'KR', 'DK', 'IT', 'AT', 'TR', 'RoW', 'BG', 'WE', 'SE'),
#        ('FI', 'LV', 'RU', 'LT'),
#        ('CH', 'RoW', 'CA', 'Europe without Switzerland'),
#        ('RoW', 'WE', 'WL', 'BR', 'WL', 'AU', 'WA'),
#        ('CA', 'CH', 'CH', 'RoW', 'CA', 'RoW'),
#        ('CN', 'CN', 'CA', 'RO', 'CA', 'ES', 'IT', 'CH', 'GB', 'CZ', 'US', 'CN', 'CA', 'CN', 'CN', 'CN', 'CA', 'EE', 'SI', 'KR', 'SE', 'AT', 'NL', 'HU', 'WM', 'BE', 'CN', 'CN', 'FI', 'TW', 'PT', 'JP', 'CN', 'WL', 'CN', 'CN', 'CN', 'CA', 'IN', 'MX', 'US', 'US', 'CA', 'US', 'CN', 'US', 'CN', 'CN', 'CN', 'BR', 'CN', 'IE', 'CN', 'AU', 'CN', 'CY', 'US', 'CN', 'BG', 'US', 'CN', 'CN', 'RoW', 'LU', 'CA', 'CN', 'GR', 'US', 'CN', 'US', 'HR', 'RU', 'FR', 'LT', 'CN', 'WL', 'CN', 'LV', 'WE', 'CA', 'DE', 'SK', 'CN', 'NO', 'DK', 'TR', 'CA', 'CN', 'CN', 'ZA', 'PL', 'CN'),
#        ('RU', 'GB', 'DE', 'CN', 'NL'),
#        ('CA', 'RoW', 'RoW', 'CA', 'CH', 'CH'),
#        ('WE', 'BG', 'WE', 'WE', 'HU'), ('ES', 'CA', 'RoW', 'FR', 'DE'),
#        ('RER', 'RoW', 'CA', 'CA', 'RER', 'RoW'), ('FR', 'IT', 'DE', 'AT'),
#        ('RoW', 'IN', 'WL', 'WL', 'WL'),
#        ('RER', 'RER', 'RoW', 'RoW', 'RoW', 'RER', 'RoW', 'RER', 'RoW', 'RER', 'RoW', 'RER', 'RoW', 'RoW', 'RER', 'RER', 'RoW', 'RER', 'RoW', 'RER'),
#        ('RoW', 'DE', 'RoW', 'RoW', 'RoW', 'DE', 'DE', 'DE'),
#        ('RoW', 'Europe without Switzerland', 'CH', 'RoW', 'CH', 'Europe without Switzerland'),
#        ('CA', 'RU', 'RoW', 'CA', 'RU', 'RoW', 'RoW', 'DE', 'CA', 'RoW', 'RoW', 'CA', 'RoW', 'WF', 'DE', 'US', 'CA', 'US', 'CA'),
#        ('RoW', 'RoW', 'BR', 'US', 'BR', 'US'), ('NL', 'FR', 'LU'),
#        ('ZA', 'WF'),
#        ('GB', 'WE', 'CZ', 'CN', 'RU', 'AT', 'MX', 'JP', 'IT', 'TR', 'ZA', 'LT', 'WL', 'ID', 'WA', 'CN', 'US', 'PT', 'RoW', 'US', 'HU', 'DE', 'PL', 'FR', 'IN', 'LV', 'CH', 'US'),
#        ('CA', 'RoW', 'CH', 'Europe without Switzerland'),
#        ('UN-OCEANIA', 'RAF', 'IAI Area, Gulf Cooperation Council', 'IAI Area, Asia, without China and GCC', 'IAI Area, EU27 & EFTA', 'RLA', 'RoW', 'RNA', 'CN', 'IAI Area, Russia & RER w/o EU27 & EFTA'),
#        ('CH', 'CH', 'RoW', 'Europe without Switzerland', 'Europe without Switzerland', 'RoW'),
#        ('US', 'FR', 'RoW'), ('PT', 'RoW', 'RoW', 'PT'),
#        ('DE', 'AT', 'PL', 'BE', 'HR', 'RoW', 'IT', 'NL', 'SK', 'CZ', 'FR', 'PT', 'ES'),
#        ('Europe without Switzerland', 'RoW', 'CH', 'CA'),
#        ('CH', 'RoW', 'US', 'Europe without Switzerland'),
#        ('WL', 'WF', 'WL', 'IN', 'US', 'WF', 'WE', 'US', 'WL', 'WA', 'CA', 'CA', 'WA', 'IN', 'WF', 'US', 'WL', 'WF', 'US', 'CH', 'WF', 'US', 'WF', 'CY', 'WA', 'CA', 'WL', 'WL', 'WM', 'US', 'WF', 'AT', 'LU', 'WE', 'WF', 'WF', 'US', 'WF', 'NL', 'WL', 'WL', 'WL', 'RoW', 'HR', 'US', 'WA', 'WL', 'AU', 'CA', 'DK', 'WL', 'WF', 'WA', 'WL', 'WF', 'US', 'DE', 'WA', 'IT', 'WA', 'WM', 'WA', 'WF', 'NO', 'WL', 'GR', 'WE', 'BR', 'WM', 'SI', 'WL', 'MT', 'WA', 'WF', 'WL', 'IN', 'WA', 'BG', 'WF', 'WF', 'WF', 'WM', 'WA', 'WE', 'WE', 'ID', 'WE', 'WF', 'ZA', 'WM', 'WF', 'WA', 'WL', 'WF', 'WM', 'WL', 'WF', 'WA', 'LV', 'WE', 'WE', 'IN', 'WL', 'WF', 'WM', 'MX', 'WL', 'JP', 'SK', 'RO', 'IE', 'CA', 'WE', 'RU', 'WE', 'WA', 'WE', 'SE', 'WL', 'TN', 'ER', 'WF', 'CA', 'WA', 'WE', 'CA', 'CA', 'ES', 'CZ', 'CA', 'WE', 'WM', 'KR', 'WM', 'FI', 'US', 'WA', 'BE', 'CA', 'WM', 'US', 'HU', 'FR', 'WA', 'WF', 'CN', 'WA', 'WM', 'WE', 'PL', 'WL', 'IN', 'WA', 'PT', 'WA', 'WF', 'WA', 'GB', 'WF', 'TR', 'CA', 'TW', 'CA', 'WF', 'CA', 'EE', 'WM', 'LT', 'WM'),
#        ('RoW', 'DE', 'AT', 'FR', 'IT', 'BE'), ('CZ', 'WE', 'HU', 'PL'),
#        ('CN', 'RU', 'RoW'), ('RER', 'RER', 'RoW', 'RoW', 'RER', 'RoW'),
#        ('WL', 'LU', 'BG', 'WL', 'WF', 'WF', 'WF', 'LT', 'WE', 'WL', 'US', 'EE', 'WL', 'WL', 'AU', 'WF', 'WF', 'WF', 'RO', 'WL', 'WE', 'FI', 'WM', 'CA', 'TN', 'CA', 'RU', 'CA', 'WF', 'DE', 'CY', 'WF', 'JP', 'WF', 'WF', 'WA', 'US', 'WM', 'WL', 'US', 'WL', 'ER', 'NO', 'FR', 'WL', 'GR', 'WM', 'WM', 'WE', 'WA', 'SE', 'WA', 'WM', 'WF', 'US', 'WF', 'BE', 'WM', 'SK', 'NL', 'CA', 'WF', 'WL', 'US', 'WA', 'WF', 'WA', 'WL', 'WE', 'WA', 'WE', 'WF', 'WM', 'WL', 'WA', 'WM', 'WF', 'CH', 'MT', 'WA', 'IN', 'PT', 'KR', 'WM', 'WE', 'IN', 'WA', 'US', 'WF', 'WF', 'WF', 'WA', 'CA', 'ID', 'IN', 'WF', 'CA', 'CA', 'WL', 'WA', 'WL', 'WE', 'US', 'RoW', 'WF', 'WM', 'WE', 'WM', 'WM', 'CZ', 'WE', 'BR', 'WA', 'AT', 'CA', 'WL', 'WM', 'WA', 'IT', 'CA', 'WA', 'US', 'CN', 'WE', 'LV', 'IE', 'WL', 'WA', 'WE', 'SI', 'IN', 'WF', 'IN', 'CA', 'US', 'WL', 'HU', 'GB', 'WL', 'WL', 'TW', 'TR', 'PL', 'WA', 'CA', 'WL', 'WF', 'WE', 'DK', 'WA', 'CA', 'WF', 'WA', 'WF', 'WA', 'CA', 'WE', 'ES', 'US', 'HR', 'WF', 'MX', 'WA', 'WL', 'US', 'WA', 'WE', 'ZA', 'WF'),
#        ('IAI Area, Russia & RER w/o EU27 & EFTA', 'RNA', 'IAI Area, EU27 & EFTA'),
#        ('RoW', 'CA', 'RoW', 'CA', 'RER', 'RER', 'RER', 'RoW', 'CA'),
#        ('RoW', 'DE', 'DE', 'DE', 'RoW', 'RoW'),
#        ('RER', 'RoW', 'RER', 'CA', 'RoW', 'RER', 'CA', 'RoW'),
#        ('US', 'RoW', 'US', 'RoW'),
#        ('RER', 'RoW', 'CA', 'CA', 'RoW', 'RER'),
#        ('RoW', 'RoW', 'RoW', 'RER', 'RER', 'RER'),
#        ('CH', 'Europe without Switzerland', 'RoW', 'CA'),
#        ('CN', 'JP', 'ZA', 'WL', 'RO', 'CN', 'ID', 'CN', 'IE', 'RoW', 'SE', 'DE', 'CN', 'CN', 'WA', 'US', 'TR', 'CN', 'CY', 'BE', 'CN', 'IN', 'CN', 'CN', 'PT', 'CA', 'CN', 'WM', 'CA', 'CN', 'BG', 'CA', 'US', 'IT', 'WM', 'CN', 'WE', 'CN', 'SK', 'US', 'US', 'NO', 'US', 'CA', 'CN', 'WE', 'CN', 'CA', 'IN', 'WA', 'GR', 'LT', 'CA', 'CN', 'CN', 'CA', 'US', 'AT', 'WE', 'DK', 'CN', 'CA', 'CA', 'MX', 'NL', 'CN', 'CN', 'WA', 'LV', 'CA', 'RU', 'SI', 'US', 'CN', 'CN', 'US', 'CZ', 'FR', 'CN', 'CN', 'HR', 'EE', 'HU', 'CN', 'TW', 'MT', 'CA', 'PL', 'CA', 'CN', 'CN', 'AU', 'CN', 'WF', 'CN', 'CA', 'US', 'CN', 'ES', 'IN', 'BR', 'WE', 'FI', 'LU', 'KR', 'GB', 'CN', 'US', 'WL'),
#        ('US', 'RoW', 'CA', 'FR', 'CA', 'DE'),
#        ('RoW', 'RoW', 'WM', 'WM', 'RoW', 'WM'), ('RoW', 'CH', 'CH'),
#        ('WE', 'HR', 'WE'),
#        ('UN-OCEANIA', 'IAI Area, Russia & RER w/o EU27 & EFTA', 'RLA', 'CN', 'IAI Area, Asia, without China and GCC', 'IAI Area, EU27 & EFTA', 'RNA'),
#        ('RoW', 'RoW', 'SE', 'SE', 'SE', 'DE', 'RoW', 'DE', 'RoW', 'DE', 'DE', 'SE', 'RoW', 'SE'),
#        ('ES',), ('RoW', 'RoW'),
#        ('RoW', 'WL', 'WL', 'WE', 'BR', 'AU', 'WA'),
#        ('CA', 'US', 'CA', 'RoW'),
#        ('IN', 'GR', 'NL', 'SE', 'RoW', 'WL', 'WE', 'WE', 'BG', 'CY', 'NO', 'WE', 'RO', 'WL', 'CZ', 'GB', 'SK', 'MT', 'BE', 'AT', 'WE', 'PT', 'FI', 'DE', 'LU', 'WE', 'LT', 'SI', 'EE', 'WE', 'ZA', 'WE', 'LV', 'HR', 'PL', 'BR', 'HU', 'IT', 'IE', 'ES', 'FR', 'CH', 'DK'),
#        ('CA', 'RoW', 'Europe without Switzerland', 'CH'),
#        ('FR', 'CN', 'EE', 'CN', 'CA', 'US', 'IN', 'TW', 'SE', 'CN', 'IN', 'CA', 'RU', 'CN', 'ZA', 'CN', 'GR', 'IN', 'CA', 'IE', 'CN', 'IN', 'CN', 'IN', 'IN', 'IT', 'TR', 'CN', 'WE', 'IN', 'CA', 'CN', 'CN', 'CN', 'KR', 'IN', 'CA', 'US', 'CN', 'CN', 'WA', 'GB', 'NL', 'IN', 'CN', 'CA', 'CN', 'CA', 'IN', 'WE', 'IN', 'CN', 'US', 'CZ', 'LU', 'CA', 'IN', 'IN', 'CN', 'CA', 'US', 'WE', 'RO', 'CN', 'US', 'CN', 'US', 'DK', 'HR', 'AU', 'CN', 'CN', 'CN', 'LV', 'WM', 'PT', 'RoW', 'CA', 'SI', 'DE', 'US', 'WE', 'WL', 'CA', 'IN', 'CN', 'LT', 'CN', 'CN', 'PL', 'IN', 'CN', 'HU', 'CN', 'US', 'CH', 'US', 'CN', 'FI', 'JP', 'CA', 'IN', 'BE', 'AT', 'US', 'ES', 'CN', 'MX', 'IN', 'IN', 'SK', 'CN', 'BG'),
#        ('IAI Area, Asia, without China and GCC', 'IAI Area, Gulf Cooperation Council', 'RAF', 'UN-OCEANIA', 'RNA', 'IAI Area, Russia & RER w/o EU27 & EFTA', 'RoW', 'CN', 'IAI Area, EU27 & EFTA', 'RLA'),
#        ('RoW', 'RER', 'RER', 'RoW', 'RER', 'RoW', 'RER', 'RoW'),
#        ('SK', 'RoW'), ('CH', 'RoW', 'CN'), ('ES', 'CN', 'RoW'),
#        ('ZA', 'ZA', 'ZA', 'ZA', 'ZA'), ('RoW', 'WL', 'RoW', 'WL'),
#        ('RAF', 'RLA', 'CN', 'IAI Area, Gulf Cooperation Council', 'RoW', 'IAI Area, EU27 & EFTA', 'RNA', 'IAI Area, Asia, without China and GCC', 'UN-OCEANIA', 'IAI Area, Russia & RER w/o EU27 & EFTA'),
#        ('DE', 'SK', 'CZ', 'SE'), ('HU', 'PL', 'WE', 'RU', 'SK', 'RO'),
#        ('AU', 'RoW'), ('RU', 'RU', 'RU', 'RU', 'RU'),
#        ('UCTE without Germany', 'DE', 'RoW'),
#        ('RNA', 'RLA', 'UN-OCEANIA', 'IAI Area, EU27 & EFTA', 'RAF', 'IAI Area, Gulf Cooperation Council', 'IAI Area, Russia & RER w/o EU27 & EFTA', 'IAI Area, Asia, without China and GCC'),
#        ('IT', 'BR', 'WE', 'IN', 'ES', 'CN', 'WL', 'US', 'RU', 'CH', 'AU', 'WA', 'MX', 'FI', 'CA', 'HU', 'NL', 'RoW', 'FR', 'WM', 'WA', 'WL', 'DE'),
#        ('BE', 'WA', 'WL', 'WL', 'ZA', 'BR', 'WF', 'WL', 'IT', 'US', 'ES', 'ID', 'WL', 'WA', 'WL', 'WA', 'WF', 'RoW', 'WF', 'MX', 'WL', 'TR', 'WL', 'FR', 'WA'),
#        ('BR', 'US', 'HR', 'IN', 'US', 'IT', 'MX', 'CA', 'IN', 'RO', 'BG', 'WE', 'RU', 'GR', 'CA', 'US', 'US', 'TW', 'US', 'WE', 'WE', 'ES', 'US', 'US', 'CA', 'RoW', 'ID', 'HU', 'WE', 'DE', 'IN', 'CA', 'SI', 'US', 'TR', 'CZ', 'KR', 'CA', 'WA', 'AU', 'US', 'US'),
#        ('CH', 'RoW', 'RoW', 'CA', 'CH', 'CA'), ('DE', 'BE'),
#        ('CH', 'DE', 'NL', 'RoW'),
#        ('RoW', 'RoW', 'CH', 'RoW', 'Europe without Switzerland', 'Europe without Switzerland', 'Europe without Switzerland'),
#        ('RoW', 'US', 'RoW', 'IN', 'IN', 'CN', 'CN'),
#        ('RoW', 'BR', 'RoW', 'RoW', 'BR', 'BR', 'RoW', 'BR'),
#        ('RoW', 'RoW', 'CA', 'CA', 'RoW', 'CA'),
#        ('DK', 'NL', 'FR', 'CH', 'SE', 'PL', 'LU', 'CZ', 'AT'),
#        ('RoW', 'CN', 'CA'),
#        ('RoW', 'CA', 'NL', 'WF', 'DE', 'RU', 'NO', 'CA'),
#        ('RoW', 'SE', 'RoW', 'SE', 'DE', 'RoW', 'DE', 'SE', 'SE', 'RoW', 'RoW', 'SE', 'DE', 'DE'),
#        ('BR', 'BE', 'WA', 'IT', 'WF', 'IN', 'MX', 'WA', 'WL', 'WL', 'RoW', 'WL', 'ES', 'ID', 'WF', 'ZA', 'CN', 'WA', 'WL', 'WL', 'US', 'WL', 'WA', 'WF', 'FR', 'WL', 'WF', 'TR'),
#        ('US', 'CA', 'CA'),
#        ('BR', 'BE', 'WA', 'US', 'WL', 'TR', 'FR', 'WA', 'WL', 'ID', 'ZA', 'CN', 'WA', 'WA', 'WF', 'WF', 'WF', 'WL', 'ES', 'MX', 'RoW', 'WL', 'WF', 'WL', 'IN', 'IT', 'WL', 'WL'),
#        ('RoW', 'CH', 'Europe without Switzerland', 'Europe without Switzerland', 'CH', 'RoW'),
#        ('IN', 'IN'), ('RER', 'RoW', 'RER', 'RoW', 'CA'),
#        ('CA', 'RoW', 'RoW', 'CA', 'CA', 'RoW'),
#        ('FR', 'WF', 'CN', 'WL', 'WL', 'WF', 'WL', 'WA', 'ES', 'BR', 'ID', 'WF', 'TR', 'WF', 'US', 'WL', 'WA', 'WL', 'WA', 'IN', 'RoW', 'WA', 'WL', 'BE', 'WL', 'IT', 'MX', 'ZA'),
#        ('RoW', 'RoW', 'RER', 'RER', 'RER', 'RER', 'RoW', 'RER', 'RER', 'RoW', 'RoW', 'RoW', 'RER', 'RoW'),
#        ('WA', 'RoW', 'ID', 'IN'), ('IN', 'RoW', 'CN'), ('WL', 'WL'),
#        ('WE', 'GR', 'WE'), ('ES', 'RoW'), ('RoW', 'US', 'CA'),
#        ('RoW', 'IT'), ('DE', 'RoW', 'NL', 'RU', 'RER w/o DE+NL+RU'),
#        ('US', 'Europe without Switzerland', 'RoW', 'CH'),
#        ('WL', 'WA', 'CA', 'RoW', 'WA', 'WL', 'CA', 'RoW'),
#        ('CH', 'CH', 'CA', 'RoW', 'CA', 'RoW'),
#        ('BR', 'WL', 'WE', 'CN', 'CN', 'CN', 'AT', 'NL', 'IN', 'LV', 'CN', 'CN', 'CN', 'CA', 'US', 'CN', 'CN', 'CN', 'CA', 'CA', 'WE', 'CA', 'CZ', 'CA', 'JP', 'DE', 'TW', 'US', 'SE', 'CN', 'CN', 'US', 'CA', 'CN', 'CA', 'HR', 'CN', 'IN', 'US', 'GB', 'BE', 'CN', 'NO', 'WA', 'US', 'RoW', 'TR', 'CN', 'BG', 'LU', 'WL', 'IN', 'IN', 'US', 'CN', 'US', 'US', 'WM', 'MX', 'IN', 'IN', 'CH', 'CN', 'LT', 'IN', 'FR', 'US', 'CN', 'CA', 'IN', 'RO', 'CN', 'DK', 'IE', 'CN', 'PT', 'PL', 'ZA', 'CA', 'CA', 'GR', 'CA', 'IT', 'CA', 'CN', 'CN', 'AU', 'EE', 'CN', 'CN', 'CN', 'HU', 'CN', 'RU', 'CN', 'SK', 'CN', 'KR', 'FI', 'CY', 'CN', 'ES', 'CN'),
#        ('WF', 'WF', 'WF', 'WF'),
#        ('ES', 'WE', 'RO', 'HR', 'ZA', 'NL', 'WE', 'FI', 'SI', 'WE', 'SE', 'NO', 'LV', 'GR', 'BR', 'CY', 'WL', 'CZ', 'PL', 'PT', 'LU', 'WE', 'DK', 'EE', 'FR', 'BG', 'CH', 'IT', 'WE', 'AT', 'RoW', 'SK', 'WL', 'GB', 'LT', 'IE', 'HU', 'WE', 'MT', 'DE', 'WE', 'BE', 'IN'),
#        ('MX', 'AT', 'BE', 'IT', 'CA', 'WE', 'HU', 'RoW', 'PL', 'IT', 'HU', 'TR', 'KR', 'JP', 'RO', 'GB', 'ES', 'WE', 'BE', 'DE', 'GB', 'SE', 'TR', 'CA', 'BR', 'CA', 'HR', 'BR', 'MX', 'DE', 'TW', 'CA', 'CA', 'CZ', 'BG', 'FR', 'FI', 'RO', 'FR', 'WM', 'CA', 'RU', 'NL', 'CA', 'KR', 'FI', 'HR', 'WE', 'CZ', 'BG', 'ES', 'WE', 'RU', 'JP', 'PL', 'CA', 'WM', 'WE', 'TW', 'SE', 'AT', 'RoW', 'SK', 'SK', 'CA', 'WE', 'NL', 'CA'),
#        ('RoW', 'RoW', 'SE', 'SE', 'RoW', 'SE', 'SE', 'RoW', 'RoW', 'SE'),
#        ('IN', 'RER'),
#        ('IN', 'IN', 'KR', 'IN', 'CN', 'RU', 'CA', 'RoW', 'IN', 'CA', 'CA', 'RO', 'IN', 'JP', 'IN'),
#        ('RoW', 'RoW', 'IN', 'IN'), ('FR',), ('ES', 'RoW', 'IT', 'CN'),
#        ('RoW', 'RER', 'RER', 'RoW', 'RoW', 'RER', 'RER', 'RoW', 'RoW', 'RER', 'RER', 'RoW', 'RER', 'RoW'),
#        ('WE', 'HU', 'US', 'NL', 'WF', 'WE', 'US', 'CA', 'WM', 'WA', 'WF', 'FR', 'BE', 'WL', 'IE', 'IT', 'WA', 'CA', 'WL', 'WL', 'WE', 'WM', 'US', 'WE', 'WF', 'MX', 'CA', 'WF', 'WM', 'JP', 'WM', 'CH', 'WF', 'WF', 'WA', 'DK', 'WF', 'BR', 'AT', 'WA', 'WF', 'WE', 'SI', 'WF', 'NO', 'KR', 'BG', 'WM', 'WF', 'ID', 'WA', 'WL', 'HR', 'WF', 'WL', 'WF', 'WM', 'WA', 'WL', 'CA', 'WA', 'SE', 'WF', 'WM', 'WA', 'WL', 'CA', 'US', 'WL', 'WE', 'WM', 'CA', 'WF', 'WF', 'WE', 'US', 'WL', 'RoW', 'WL', 'WE', 'WA', 'WF', 'WL', 'CA', 'GR', 'WM', 'CZ', 'WF', 'WF', 'AU', 'CA', 'WA', 'LU', 'WF', 'WF', 'WE', 'WL', 'WF', 'PT', 'US', 'WL', 'TR', 'WA', 'US', 'ER', 'WE', 'WA', 'ES', 'WE', 'WF', 'RO', 'WA', 'WA', 'DE', 'WM', 'ZA', 'US', 'WM', 'RU', 'WL', 'WL', 'CA', 'WE', 'WL', 'WF', 'WM', 'WA', 'WL', 'WA', 'WF', 'PL', 'WA', 'WF', 'FI', 'WM', 'CA', 'WA', 'CA', 'CA', 'WA', 'US', 'TN', 'WE', 'TW', 'WL', 'WA', 'WL', 'SK', 'WL', 'US', 'CA', 'WL', 'WA', 'WF', 'GB', 'WF', 'LT', 'IN', 'WE', 'EE', 'IN', 'LV', 'CY', 'CN', 'IN', 'MT', 'IN', 'US', 'IN'),
#        ('MX', 'PT', 'HR', 'RO', 'US', 'ZA', 'CA', 'HU', 'TW', 'CZ', 'CN', 'WE', 'CA', 'CN', 'CN', 'CN', 'GR', 'WF', 'WL', 'CN', 'CN', 'RoW', 'CN', 'KR', 'CA', 'CN', 'CN', 'US', 'BE', 'US', 'FR', 'ES', 'CN', 'AU', 'US', 'WE', 'FI', 'CA', 'GB', 'LT', 'CN', 'SE', 'CN', 'WA', 'CN', 'CH', 'CA', 'NL', 'CN', 'PL', 'CN', 'CY', 'CN', 'WA', 'CN', 'MT', 'CN', 'DE', 'WM', 'IT', 'CN', 'SK', 'CA', 'CN', 'BG', 'CN', 'CN', 'CA', 'CN', 'LU', 'CN', 'TR', 'CA', 'CN', 'RU', 'US', 'CA', 'DK', 'CN', 'CN', 'CA', 'US', 'AT', 'WE', 'US', 'CN', 'JP', 'CA', 'SI', 'CA', 'CN', 'ID', 'CN'),
#        ('HR', 'WE', 'ES', 'WE', 'CZ', 'LU', 'ZA', 'SE', 'DK', 'GB', 'NL', 'WE', 'WE', 'WL', 'HU', 'PL', 'FI', 'BR', 'RoW', 'AT', 'WL', 'MT', 'BG', 'IN', 'DE', 'SI', 'PT', 'CH', 'GR', 'FR', 'BE', 'LV', 'LT', 'WE', 'WE', 'IE', 'WE', 'CY', 'RO', 'SK', 'EE', 'IT', 'NO'),
#        ('CN', 'RoW', 'IN', 'WL'), ('UCTE', 'RoW'),
#        ('RoW', 'RER', 'RER', 'RoW', 'RoW', 'RER', 'RoW', 'RoW', 'RER', 'RER', 'RoW', 'RER'),
#        ('CA', 'Europe without Switzerland', 'RoW', 'RoW', 'RoW', 'RoW', 'RoW', 'CA', 'Europe without Switzerland', 'Europe without Switzerland', 'Europe without Switzerland', 'CA', 'CA', 'CA', 'Europe without Switzerland'),
#        ('WF', 'NO'), ('RER', 'RoW', 'RER', 'RER', 'RoW', 'RoW'),
#        ('CH', 'RoW', 'CH', 'RoW', 'CA', 'CA'), ('RoW', 'WF'),
#        ('RoW', 'CH', 'RoW'), ('AU', 'US', 'WF', 'ZA', 'RoW', 'CA'),
#        ('TW', 'WE', 'CN', 'US', 'IN', 'CA', 'WM', 'CN', 'IN', 'CN', 'CN', 'CN', 'CA', 'US', 'CA', 'WF', 'IE', 'CN', 'WA', 'PL', 'CN', 'IN', 'IN', 'CN', 'WA', 'IN', 'CN', 'CN', 'CA', 'RU', 'US', 'IN', 'IN', 'HR', 'CN', 'CN', 'CN', 'IN', 'CA', 'ZA', 'CA', 'CN', 'MX', 'BG', 'TR', 'IN', 'GR', 'BR', 'HU', 'CA', 'CN', 'IN', 'IN', 'LU', 'RO', 'US', 'CN', 'FI', 'CH', 'SI', 'AT', 'CN', 'CN', 'AU', 'ES', 'KR', 'CN', 'CA', 'LV', 'CA', 'US', 'CA', 'NL', 'IN', 'SE', 'CN', 'ID', 'CZ', 'IN', 'DK', 'LT', 'CN', 'IN', 'CA', 'WE', 'GB', 'CY', 'CN', 'WE', 'US', 'PT', 'CA', 'US', 'IN', 'IT', 'FR', 'BE', 'IN', 'SK', 'CN', 'CN', 'IN', 'IN', 'DE', 'CN', 'CN', 'CN', 'CN', 'IN', 'RoW', 'JP', 'WL', 'CN', 'MT', 'WA'),
#        ('CN', 'RER', 'IN'), ('WF', 'ID', 'WF', 'RoW'),
#        ('BE', 'FR', 'US', 'CN', 'DE', 'CN', 'US', 'CN', 'CA', 'IN', 'ES', 'RU', 'CA', 'CN', 'CN', 'IN', 'GR', 'CN', 'BR', 'CN', 'CA', 'CA', 'WM', 'CN', 'CZ', 'IN', 'US', 'AT', 'IN', 'IE', 'CN', 'CN', 'US', 'US', 'US', 'WL', 'IN', 'CN', 'US', 'CN', 'CN', 'WE', 'KR', 'CA', 'PT', 'RoW', 'TW', 'WA', 'TR', 'CN', 'CN', 'NL', 'CN', 'CA', 'CN', 'IN', 'CN', 'IN', 'CN', 'US', 'CN', 'IN', 'CN', 'CN', 'CN', 'MX', 'FI', 'AU', 'JP', 'CA', 'SK', 'IT', 'NO', 'HR', 'CN', 'CA', 'IN', 'WF', 'CN', 'CN', 'US', 'IN', 'CN', 'IN', 'CN', 'WM', 'IN', 'GB', 'CA', 'WA', 'CA', 'ID', 'HU', 'CN', 'RO', 'CN', 'BG', 'SI', 'WL', 'IN', 'CN'),
#        ('IE', 'FI', 'RoW', 'MT', 'BG', 'GB', 'LV', 'WE', 'SK', 'EE', 'FR', 'HR', 'WE', 'BR', 'PL', 'PT', 'BE', 'WL', 'ES', 'CZ', 'WE', 'HU', 'WE', 'SI', 'CY', 'LU', 'NO', 'DK', 'DE', 'IN', 'GR', 'WE', 'ZA', 'IT', 'RO', 'LT', 'NL', 'AT', 'WL', 'WE', 'CH', 'SE', 'WE'),
#        ('RoW', 'NL'),
#        ('NO', 'SE', 'RoW', 'SK', 'ES', 'DK', 'FI', 'CZ', 'CH', 'JP', 'PL', 'KR', 'NL', 'AT', 'RU', 'BE', 'LU', 'IT', 'HU', 'PT', 'GB', 'FR', 'BG', 'DE', 'TW', 'TR'),
#        ('WE', 'WE', 'WE'), ('UCTE without Germany', 'RoW', 'DE'),
#        ('WE', 'ES', 'RO', 'SI', 'SE', 'GB', 'FI', 'GR', 'AT', 'PL', 'CY', 'BR', 'CH', 'LV', 'FR', 'WE', 'HR', 'LT', 'HU', 'SK', 'WE', 'CZ', 'MT', 'NO', 'WL', 'WE', 'LU', 'RoW', 'PT', 'DE', 'IT', 'IE', 'DK', 'EE', 'WE', 'WL', 'WE', 'NL', 'BG', 'IN', 'ZA', 'BE', 'WE'),
#        ('NO', 'WM', 'CN', 'FI', 'GB', 'IT', 'EE', 'CN', 'KR', 'JP', 'WE', 'BG', 'BR', 'CN', 'KR', 'CN', 'CN', 'CN', 'CN', 'HU', 'CA', 'CN', 'CN', 'CN', 'CN', 'CZ', 'NO', 'WE', 'CN', 'FR', 'CN', 'CN', 'AU', 'CZ', 'CN', 'CN', 'WE', 'CN', 'CN', 'CN', 'GB', 'AT', 'CN', 'WE', 'NL', 'CN', 'CN', 'CA', 'RO', 'WE', 'CN', 'CA', 'BE', 'CN', 'MX', 'CN', 'SE', 'CN', 'ES', 'RoW', 'AT', 'NL', 'BR', 'CN', 'HR', 'TR', 'CN', 'CN', 'HR', 'CN', 'RU', 'CN', 'CN', 'CN', 'CN', 'BG', 'RoW', 'CN', 'CN', 'WM', 'FI', 'HU', 'IE', 'IE', 'PL', 'CN', 'CN', 'CA', 'CN', 'FR', 'CN', 'IT', 'CN', 'EE', 'SK', 'CN', 'CN', 'DE', 'CN', 'CN', 'CN', 'CN', 'SE', 'SK', 'CN', 'CN', 'CN', 'CN', 'MX', 'CN', 'AU', 'CN', 'PL', 'BE', 'CN', 'TW', 'JP', 'WE', 'RU', 'CN', 'CN', 'CA', 'CA', 'RO', 'CN', 'ES', 'TR', 'CN', 'CA', 'CN', 'CN', 'CA', 'TW', 'DE', 'CN', 'CN', 'CA', 'CA'),
#        ('RoW', 'CH', 'RU', 'DE', 'FR', 'US')], dtype=object)

# %%
PRO_f['list_geo']
# Out:
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3f9c-4074-bd34-eba76a61760c    NaN
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3f9c-4074-bd34-eba76a61760c    NaN
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c05d-410a-a784-06e3508e78e6    NaN
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1a25-41b4-a821-81f5726d86e5    NaN
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1a25-41b4-a821-81f5726d86e5    NaN
#                                                                             ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d00c-5713-823d-5ff6741bfbbc    NaN
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7d6a-55d2-8380-86343a80fed8    NaN
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c6c8-56a7-a518-b01dd3e8a453    NaN
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2da0-528b-96fd-21687e242c1c    NaN
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d9e6-4396-9f9a-97e752111228    NaN
# Name: list_geo, Length: 16022, dtype: object

# %%
df_aggregated = pd.DataFrame(
        data = PRO_f.groupby('activityNameId')['io_geography'].apply(list)
    )

# %%
df_aggregated[df_aggregated['io_geography'].apply(lambda x: bool(set(x) & set(['RoW'])))]
# Out:
#                                                                            io_geography
# activityNameId
# 003682ba-f70c-474f-ba5f-8203d2d00512  [HR, MX, WA, LT, HR, LT, WA, RU, ID, WL, LV, W...
# 00414c23-6514-4699-9d90-71e9cf9a0262              [CH, RoW, Europe without Switzerland]
# 00431801-ae3e-4836-aca5-838071f41957                                         [RER, RoW]
# 0043d228-ff21-4697-9e99-897c9bb4a6e5               [BR, BR, US, US, RER, RoW, RoW, RER]
# 0055a295-7c95-46c1-8baa-1a9bf2a364b5                          [RoW, WF, RU, NO, NL, DE]
# ...                                                                                 ...
# ff7f2df7-3797-40f0-bef5-2de2b6c1f4ef                                          [CH, RoW]
# ff98d350-178d-463c-873a-e78a2be05336                                         [RoW, RER]
# ffc05716-a13b-4d62-a9ea-b5ca4a738945                                         [RoW, RER]
# ffd2d364-1641-4b66-a350-455eff193e37                          [RoW, CH, RU, DE, FR, US]
# fff34601-b48b-43ea-89da-3e33d8f4df5a                                         [RoW, RER]
#
# [2981 rows x 1 columns]

# %%
df_aggregated['io_geography']
# Out:
# activityNameId
# 0021a538-9534-4fd4-835e-a2fa8f76bb9d                                                [GLO]
# 002477cd-70fa-49c1-afc3-c372abbcf72b                                                [GLO]
# 002fa54c-1829-4231-82ed-47e35a6745d4                                                [GLO]
# 003682ba-f70c-474f-ba5f-8203d2d00512    [HR, MX, WA, LT, HR, LT, WA, RU, ID, WL, LV, W...
# 003a2fba-a774-4ff8-b8da-3adb2e14aeba                                                [GLO]
#                                                               ...
# ffb6f7f9-766a-40b8-9401-8ffb6599310b                                                [GLO]
# ffc05716-a13b-4d62-a9ea-b5ca4a738945                                           [RoW, RER]
# ffd2d364-1641-4b66-a350-455eff193e37                            [RoW, CH, RU, DE, FR, US]
# ffe2f2d1-4266-4992-b0e6-836c27fb8457                                                [GLO]
# fff34601-b48b-43ea-89da-3e33d8f4df5a                                           [RoW, RER]
# Name: io_geography, Length: 6676, dtype: object

# %%
df = df_aggregated

# %%
df[df['io_geography'].isin(['GLO'])]
# Out:
# Empty DataFrame
# Columns: [io_geography]
# Index: []

# %%
df_aggregated[df_aggregated['io_geography'].str.contains('GLO').any(axis='columns').values]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/pylcaio/lib/python3.10/site-packages/pandas/core/generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'columns'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [43], line 1
# ----> 1 df_aggregated[df_aggregated['io_geography'].str.contains('GLO').any(axis='columns').values]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/pylcaio/lib/python3.10/site-packages/pandas/core/generic.py:10891, in NDFrame._add_numeric_operations.<locals>.any(self, axis, bool_only, skipna, level, **kwargs)
#   10880 @doc(
#   10881     _bool_doc,
#   10882     desc=_any_desc,
#    (...)
#   10889 )
#   10890 def any(self, axis=0, bool_only=None, skipna=True, level=None, **kwargs):
# > 10891     return NDFrame.any(self, axis, bool_only, skipna, level, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/pylcaio/lib/python3.10/site-packages/pandas/core/generic.py:10466, in NDFrame.any(self, axis, bool_only, skipna, level, **kwargs)
#   10458 def any(
#   10459     self,
#   10460     axis: Axis = 0,
#    (...)
#   10464     **kwargs,
#   10465 ) -> Series | bool_t:
# > 10466     return self._logical_func(
#   10467         "any", nanops.nanany, axis, bool_only, skipna, level, **kwargs
#   10468     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/pylcaio/lib/python3.10/site-packages/pandas/core/generic.py:10449, in NDFrame._logical_func(self, name, func, axis, bool_only, skipna, level, **kwargs)
#   10446         obj = self._get_bool_data()
#   10447     return obj._reduce_axis1(name, func, skipna=skipna)
# > 10449 return self._reduce(
#   10450     func,
#   10451     name=name,
#   10452     axis=axis,
#   10453     skipna=skipna,
#   10454     numeric_only=bool_only,
#   10455     filter_type="bool",
#   10456 )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/pylcaio/lib/python3.10/site-packages/pandas/core/series.py:4455, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4452 delegate = self._values
#    4454 if axis is not None:
# -> 4455     self._get_axis_number(axis)
#    4457 if isinstance(delegate, ExtensionArray):
#    4458     # dispatch to ExtensionArray interface
#    4459     return delegate._reduce(name, skipna=skipna, **kwds)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/pylcaio/lib/python3.10/site-packages/pandas/core/generic.py:552, in NDFrame._get_axis_number(cls, axis)
#     550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
# --> 552     raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named columns for object type Series

# %%
PRO_f = pylcaio_object_before_hybrid.PRO_f

# %%
PRO_f.columns
# Out:
# Index(['activityId', 'productId', 'activityName', 'ISIC', 'price', 'priceUnit',
#        'EcoSpoldCategory', 'geography', 'technologyLevel',
#        'macroEconomicScenario', 'wet mass [kg]_x', 'dry mass [kg]_x',
#        'productionVolume', 'productName', 'unitName', 'cpc', 'dry mass [kg]_y',
#        'wet mass [kg]_y', 'activityNameId', 'activityType', 'startDate',
#        'endDate', 'activityName_duplicate', 'io_geography', 'ProductTypeName'],
#       dtype='object')

# %%
identify_rest_of_world_regions(
    df = PRO_f,
    list_io_countries_and_regions = list_io_countries_and_regions,
    dict_io_countries_per_lca_region = dict_io_countries_per_lca_region
)
# Out:
#                                                                               activityId  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...  a96cb241-a4a9-4980-a16a-ba4b6a80175e
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...  6885fd40-ff73-40a4-8f71-225577ec684e
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...  d1c3b8ad-58b6-4ea4-8877-a51b356556bc
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...  92068396-88c7-45ed-9008-622008a299f3
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...  35ddb020-9812-4808-bdfb-6845a454a73c
# ...                                                                                  ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...  31e6ab74-141d-49f4-9e75-5974bd62742b
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...  b50b032c-8bf0-41a4-bb7a-ce5e12cabf01
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...  307b681d-c6bc-44cb-ab3e-a9067a4e115a
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...  73c9e29c-885e-490e-95f3-087227443758
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...  91ed532a-08f2-4fdd-b5e9-28bb2afd1336
#
#                                                                                productId  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...  aeaf5266-3f9c-4074-bd34-eba76a61760c
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...  aeaf5266-3f9c-4074-bd34-eba76a61760c
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...  281fc4f0-c05d-410a-a784-06e3508e78e6
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...  0d860eb4-1a25-41b4-a821-81f5726d86e5
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...  0d860eb4-1a25-41b4-a821-81f5726d86e5
# ...                                                                                  ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...  b3184435-d00c-5713-823d-5ff6741bfbbc
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...  d13ae29b-7d6a-55d2-8380-86343a80fed8
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...  ed25f589-c6c8-56a7-a518-b01dd3e8a453
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...  101e55f2-2da0-528b-96fd-21687e242c1c
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...  451550a8-d9e6-4396-9f9a-97e752111228
#
#                                                                                          activityName  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...                      barley grain, feed production
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...                      barley grain, feed production
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...  barley grain, feed production, Swiss integrate...
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...             barley grain, feed production, organic
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...             barley grain, feed production, organic
# ...                                                                                               ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...  waste polyethylene terephthalate, for recyclin...
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...  waste polyethylene terephthalate, for recyclin...
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...  waste polyethylene, for recycling, sorted, Rec...
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...  waste polyethylene, for recycling, unsorted, R...
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...  waste wood, post-consumer, Recycled Content cu...
#
#                                                                                                  ISIC  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...  0111:Growing of cereals (except rice), legumin...
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...  0111:Growing of cereals (except rice), legumin...
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...  0111:Growing of cereals (except rice), legumin...
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...  0111:Growing of cereals (except rice), legumin...
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...  0111:Growing of cereals (except rice), legumin...
# ...                                                                                               ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...                                                NaN
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...                                                NaN
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...                                                NaN
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...                                                NaN
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...                                                NaN
#
#                                                     price priceUnit  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...  0.124   EUR2005
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...  0.124   EUR2005
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...  0.124   EUR2005
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...  0.159   EUR2005
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...  0.159   EUR2005
# ...                                                   ...       ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...  0.000       NaN
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...  0.000       NaN
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...  0.000       NaN
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...  0.000       NaN
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...  0.000       NaN
#
#                                                                          EcoSpoldCategory  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...  agricultural means of production/feed
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...  agricultural means of production/feed
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...  agricultural means of production/feed
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...  agricultural means of production/feed
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...  agricultural means of production/feed
# ...                                                                                   ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...                                    NaN
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...                                    NaN
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...                                    NaN
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...                                    NaN
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...                                    NaN
#
#                                                    geography technologyLevel  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...     CA-QC         Current
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...       RoW         Current
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...        CH         Current
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...        CH         Current
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...       RoW         Current
# ...                                                      ...             ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...       GLO         Current
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...       GLO         Current
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...       GLO         Current
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...       GLO         Current
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...       GLO         Current
#
#                                                    macroEconomicScenario  ...  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...     Business-as-Usual  ...
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...     Business-as-Usual  ...
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...     Business-as-Usual  ...
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...     Business-as-Usual  ...
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...     Business-as-Usual  ...
# ...                                                                  ...  ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...     Business-as-Usual  ...
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...     Business-as-Usual  ...
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...     Business-as-Usual  ...
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...     Business-as-Usual  ...
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...     Business-as-Usual  ...
#
#                                                    dry mass [kg]_y  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...            0.86
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...            0.86
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...            0.85
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...            0.85
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...            0.85
# ...                                                            ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...             NaN
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...             NaN
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...             NaN
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...             NaN
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...               1
#
#                                                    wet mass [kg]_y  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...               1
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...               1
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...               1
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...               1
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...               1
# ...                                                            ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...             NaN
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...             NaN
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...             NaN
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...             NaN
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...             1.4
#
#                                                                           activityNameId  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...  2816d5b0-50fd-42fd-9bc9-aed0bd1913e7
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...  2816d5b0-50fd-42fd-9bc9-aed0bd1913e7
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...  938a1c4e-41f2-40ea-9bf1-9f09c2437798
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...  6a49a0c6-c114-4471-b6c4-8aa4006e4b0e
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...  6a49a0c6-c114-4471-b6c4-8aa4006e4b0e
# ...                                                                                  ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...  712ffc38-2281-4fd2-a84d-089678e23bd3
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...  27dcd766-bc63-4a7c-9fdf-ffc55e0575b2
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...  40de0860-eadc-43ae-bdbf-5e507563379a
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...  06f4a8b9-d8b2-42d1-94e4-9da5e9420754
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...  e413d513-3e07-4f5a-ba52-b3bfdf3dc9a5
#
#                                                    activityType   startDate  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...            0  1996-01-01
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...            0  1996-01-01
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...            0  1996-01-01
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...            0  1996-01-01
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...            0  1996-01-01
# ...                                                         ...         ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...            0  2018-01-01
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...            0  2018-01-01
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...            0  2018-01-01
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...            0  2018-01-01
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...            0  2018-01-01
#
#                                                        endDate  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...  2018-12-31
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...  2018-12-31
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...  2018-12-31
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...  2018-12-31
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...  2018-12-31
# ...                                                        ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...  2018-12-31
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...  2018-12-31
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...  2018-12-31
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...  2018-12-31
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...  2018-12-31
#
#                                                                                activityName_duplicate  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...                      barley grain, feed production
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...                      barley grain, feed production
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...  barley grain, feed production, Swiss integrate...
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...             barley grain, feed production, organic
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...             barley grain, feed production, organic
# ...                                                                                               ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...  waste polyethylene terephthalate, for recyclin...
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...  waste polyethylene terephthalate, for recyclin...
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...  waste polyethylene, for recycling, sorted, Rec...
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...  waste polyethylene, for recycling, unsorted, R...
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...  waste wood, post-consumer, Recycled Content cu...
#
#                                                    io_geography  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...           CA
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...          RoW
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...           CH
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...           CH
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...          RoW
# ...                                                         ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...          GLO
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...          GLO
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...          GLO
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...          GLO
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...          GLO
#
#                                                       ProductTypeName  \
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...  Cereal grains nec
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...  Cereal grains nec
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...  Cereal grains nec
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...  Cereal grains nec
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...  Cereal grains nec
# ...                                                               ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...                NaN
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...                NaN
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...                NaN
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...                NaN
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...                NaN
#
#                                                     list_io_geography
# a96cb241-a4a9-4980-a16a-ba4b6a80175e_aeaf5266-3...                NaN
# 6885fd40-ff73-40a4-8f71-225577ec684e_aeaf5266-3...                NaN
# d1c3b8ad-58b6-4ea4-8877-a51b356556bc_281fc4f0-c...                NaN
# 92068396-88c7-45ed-9008-622008a299f3_0d860eb4-1...                NaN
# 35ddb020-9812-4808-bdfb-6845a454a73c_0d860eb4-1...                NaN
# ...                                                               ...
# 31e6ab74-141d-49f4-9e75-5974bd62742b_b3184435-d...                NaN
# b50b032c-8bf0-41a4-bb7a-ce5e12cabf01_d13ae29b-7...                NaN
# 307b681d-c6bc-44cb-ab3e-a9067a4e115a_ed25f589-c...                NaN
# 73c9e29c-885e-490e-95f3-087227443758_101e55f2-2...                NaN
# 91ed532a-08f2-4fdd-b5e9-28bb2afd1336_451550a8-d...                NaN
#
# [16022 rows x 26 columns]

# %%
def identify_rows(self):
    """ Method to identify the various unique Rest of the World (RoW) regions of the LCA database

    Returns:
    --------
        The updated self.dictRoW in which unique RoW regions are identified in terms of countries they include

    """

    # contains a list of activityNameId's that are 'PRO_f.io_geography[i]=='RoW (=LCA RoW)'
    unique_activities_using_row = list(
        set( # removes duplicates
            self.PRO_f.activityNameId[ # nota bene: activityNameId is Master Data!
                [i for i in self.PRO_f.index if self.PRO_f.io_geography[i] == 'RoW']].tolist()
        )
    )

    RoW_activities = defaultdict(list)

    # how and WHERE are `geography` and `io_geography` matched?

    # list of tuples (activityNameId (=Master Data), geography)
    # where activityNameId where one of the geographis is 'RoW' and
    # where geography is a list of all regions that are associated with one activityNameId
    tupl = [  
        i for i in zip( # zip creates tuple
            self.PRO_f.activityNameId.loc[
                [
                    i for i in self.PRO_f.index
                    if self.PRO_f.activityNameId[i] in unique_activities_using_row
                ]
            ],
            self.PRO_f.io_geography.loc[
                [
                    i for i in self.PRO_f.index
                    if self.PRO_f.activityNameId[i] in unique_activities_using_row
                ]
            ]
        )
    ]

    # ok, dictionary is filled
    for activity, geography in tupl:
        RoW_activities[activity].append(geography)

    # remove 'RoW' from dict values
    RoW_activities = {activity: [geography1 for geography1 in geography if geography1 != 'RoW'] for activity, geography in RoW_activities.items()}

    # delete from RoW_activities processes which had only RoW as geography and are thus empty now
    for key in [i for i in list(RoW_activities.keys()) if RoW_activities[i] == []]:
        del RoW_activities[key]
        
    # put every element to the same level (elements that are lists are transformed to lists of lists)
    for values in list(RoW_activities.values()):
        for i in range(0, len(values)):
            if values[i] in self.countries_per_regions.keys():
                values[i] = self.countries_per_regions[values[i]]

    # for elements that are lists of lists stemming from the replacement of ['RER'] by [['AT','BE',...]],
    # add all of the together in a single list
    for keys in RoW_activities.keys():
        for item in RoW_activities[keys]:
            if isinstance(item, list):
                RoW_activities[keys] = sum_elements_list(RoW_activities[keys])
    # remove duplicates inside the elements
    for keys in list(RoW_activities.keys()):
        RoW_activities[keys] = list(set(RoW_activities[keys]))

    # why sort here? to ensure unique_RoWs does not contain duplicates that would just have a different order
    # need to sort to identify duplicates whose elements would be ordered differently and thus be treated as not duplicated
    for keys in RoW_activities.keys():
        RoW_activities[keys].sort()

    # identify the combination of countries that are NOT inside the residual of each process
    # dict where
    # key = activityNameId
    # value = list of IO countries that are NOT associated with activityNameId
    dictactrow = {}
    residual_geo_IO_to_remove = ['WA', 'WE', 'WF', 'WL', 'WM'] # exiobase 'rest of world' regions (all other are actual countries)
    for keys in RoW_activities.keys():
        dictactrow[keys] = list( # dictactrow[keys] is activityNameId
            set(self.listcountry) # countries + RoW regions IO
            - set(RoW_activities[keys]) # countries LCA associated with the activityNameId
            - set(residual_geo_IO_to_remove)) # RoW regions IO
    
    unique_RoWs = []
    for keys in dictactrow.keys():
        if dictactrow[keys] not in unique_RoWs:
            unique_RoWs.append(dictactrow[keys])

    # create name for the values of the different RoW
    listname = []
    for i in range(0, len(unique_RoWs)):
        listname.append('RoW' + '(' + str(i) + ')')
    
    # put all of that in dictRoW
    # dictRow is created empty earlier in the code
    for i in range(0, len(unique_RoWs)):
        self.dictRoW[listname[i]] = unique_RoWs[i]
    try:
        # if RoWs are empty because processes from ecoinvent are too described
        del [[k for k in self.dictRoW.keys() if len(self.dictRoW[k]) == 0][0]]
    except IndexError:
        pass

    # replace RoW list (eg. [AT, DE, ...] with RoW number (eg. RoW(1)))
    for activityNameId in dictactrow: # key = activityNameId
        for RoW_number in self.dictRoW: # key = eg. "RoW(12)"
            if dictactrow[activityNameId] == self.dictRoW[RoW_number]: # dictactrow[activityNameId] = RoW list, self.dictRoW[RoW_number]
                dictactrow[activityNameId] = RoW_number

    RoW_matrix = pd.DataFrame(
        data = list(dictactrow.values()),
        index=list(dictactrow.keys()),
        columns=['RoW_geography']
    )

    # adds RoW information to matrix
    self.PRO_f = self.PRO_f.merge(RoW_matrix, left_on='activityNameId', right_on=RoW_matrix.index, how='outer')

    self.PRO_f.index = self.PRO_f.activityId + '_' + self.PRO_f.productId
    self.PRO_f = self.PRO_f.reindex(self.processes_in_order)
    
    self.PRO_f.io_geography.update(self.PRO_f.RoW_geography[self.PRO_f.io_geography == 'RoW'])
    self.PRO_f = self.PRO_f.drop('RoW_geography', axis=1)

    # might be some RoW or empty lists left in PRO_f
    self.PRO_f.io_geography[self.PRO_f.io_geography == 'RoW'] = 'GLO'
    self.PRO_f.io_geography.loc[[i for i in self.PRO_f.index if type(self.PRO_f.io_geography[i]) == list]] = 'GLO'
